# %% [markdown]
# <a id="table_of_content"></a>

# %% [markdown]
# # Part 1: Bag-of-Words Exercises
#
# In the following, we will convert our corpus of 10-k documents into bag-of-words, and convert them into document vectors using Term-Frequency-Inverse-Document-Frequency (tf-idf) re-weighting. Afterward, we will compute sentiments and similarity metrics. Since we will be reusing our notebook, so the various sections are linked below:
#
# 1. <a href="#bag_of_word">Compute bag-of-words </a>: implement `bag_of_words` that converts tokenized words into a dictionary of word-counts
#
# 2. <a href="#sentiment">Sentiments </a>: using wordlists, compute positive and negative sentiments from bag-of-words. Implement `get_sentiment`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`
#
# # Part 2: Document-Vector Exercises
#
# 3. <a href="#compute_idf">Compute idf </a>: computing the inverse document frequency, implement `get_idf`
#
# 4. <a href="#compute_tf">Compute tf </a>: computing the term frequency, implement `get_tf`
#
# 5. <a href="#doc_vector">Document vector </a>: using the functions `get_idf` and `get_tf`, compute a word_vector for each document in the corpus
# 6. <a href="#similarity">Similarities </a>: comparing two vectors, and compute cosine and jacard similarity metrics. Implement `get_cos` and `get_jac`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`

# %% [markdown]
# ## 0. Initialization
#
# First we read in our 10-k documents

# %%
# download some excerpts from 10-K files
from download10k import get_files

CIK = {'ebay': '0001065088', 'apple':'0000320193', 'sears': '0001310067'}
get_files(CIK['ebay'], 'EBAY')
get_files(CIK['apple'], 'AAPL')
get_files(CIK['sears'], 'SHLDQ')


# get a list of all 10-ks in our directory
files=! ls *10k*.txt
print("10-k files: ",files)
files = [open(f,"r").read() for f in files]
# Out:
# downloading 10-Ks item 1A for CIK = 0001065088 ...
# writing EBAY_10k_2017.txt...
# writing EBAY_10k_2016.txt...
# writing EBAY_10k_2015.txt...
# writing EBAY_10k_2014.txt...
# writing EBAY_10k_2013.txt...
# downloading 10-Ks item 1A for CIK = 0000320193 ...
# downloading 10-Ks item 1A for CIK = 0001310067 ...
# writing SHLDQ_10k_2017.txt...
# writing SHLDQ_10k_2016.txt...
# writing SHLDQ_10k_2015.txt...
# writing SHLDQ_10k_2014.txt...
# writing SHLDQ_10k_2013.txt...
# 10-k files:  ['EBAY_10k_2013.txt', 'EBAY_10k_2014.txt', 'EBAY_10k_2015.txt', 'EBAY_10k_2016.txt', 'EBAY_10k_2017.txt', 'SHLDQ_10k_2013.txt', 'SHLDQ_10k_2014.txt', 'SHLDQ_10k_2015.txt', 'SHLDQ_10k_2016.txt', 'SHLDQ_10k_2017.txt']

# %% [markdown]
# here we define useful functions to tokenize the texts into words, remove stop-words, and lemmatize and stem our words

# %%
import numpy as np

# for nice number printing
np.set_printoptions(precision=3, suppress=True)

# tokenize and clean the text
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from collections import Counter
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
# tokenize anything that is not a number and not a symbol
word_tokenizer = RegexpTokenizer(r'[^\d\W]+')

nltk.download('stopwords')
nltk.download('wordnet')


sno = SnowballStemmer('english')
wnl = WordNetLemmatizer()

# get our list of stop_words
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 
# add some extra stopwords
stop_words |= {"may", "business", "company", "could", "service", "result", "product", 
               "operation", "include", "law", "tax", "change", "financial", "require",
               "cost", "market", "also", "user", "plan", "actual", "cash", "other",
               "thereto", "thereof", "therefore"}

# useful function to print a dictionary sorted by value (largest first by default)
def print_sorted(d, ascending=False):
    factor = 1 if ascending else -1
    sorted_list = sorted(d.items(), key=lambda v: factor*v[1])
    for i, v in sorted_list:
        print("{}: {:.3f}".format(i, v))

# convert text into bag-of-words
def clean_text(txt):
    lemm_txt = [ wnl.lemmatize(wnl.lemmatize(w.lower(),'n'),'v') \
                for w in word_tokenizer.tokenize(txt) if \
                w.isalpha() and w not in stop_words ]
    return [ sno.stem(w) for w in lemm_txt if w not in stop_words and len(w) > 2 ]

corpus = [clean_text(f) for f in files]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus
# Out:
# [['risk',
#   'factor',
#   'affect',
#   'condit',
#   'subject',
#   'various',
#   'risk',
#   'uncertainti',
#   'advers',
#   'affect',
#   'condit',
#   'flow',
#   'well',
#   'trade',
#   'price',
#   'common',
#   'stock',
#   'debt',
#   'offer',
#   'oper',
#   'vari',
#   'quarter',
#   'basi',
#   'oper',
#   'histori',
#   'oper',
#   'fluctuat',
#   'signific',
#   'varieti',
#   'factor',
#   'mani',
#   'outsid',
#   'control',
#   'factor',
#   'affect',
#   'oper',
#   'risk',
#   'describ',
#   'elsewher',
#   'section',
#   'follow',
#   'general',
#   'econom',
#   'condit',
#   'possibl',
#   'prolong',
#   'period',
#   'limit',
#   'econom',
#   'growth',
#   'possibl',
#   'econom',
#   'declin',
#   'europ',
#   'advers',
#   'effect',
#   'ongo',
#   'sovereign',
#   'debt',
#   'crisi',
#   'europ',
#   'increas',
#   'euro',
#   'currenc',
#   'exchang',
#   'rate',
#   'volatil',
#   'negat',
#   'impact',
#   'crisi',
#   'relat',
#   'auster',
#   'measur',
#   'european',
#   'econom',
#   'growth',
#   'potenti',
#   'negat',
#   'spillov',
#   'effect',
#   'rest',
#   'world',
#   'contagion',
#   'risk',
#   'crisi',
#   'spread',
#   'addit',
#   'countri',
#   'europ',
#   'possibl',
#   'one',
#   'countri',
#   'leav',
#   'euro',
#   'zone',
#   'introduc',
#   'individu',
#   'currenc',
#   'extrem',
#   'circumst',
#   'possibl',
#   'dissolut',
#   'euro',
#   'currenc',
#   'possibl',
#   'greater',
#   'auster',
#   'due',
#   'among',
#   'factor',
#   'automat',
#   'sequest',
#   'failur',
#   'rais',
#   'debt',
#   'ceil',
#   'relat',
#   'action',
#   'failur',
#   'take',
#   'action',
#   'congress',
#   'execut',
#   'branch',
#   'general',
#   'impact',
#   'uncertainti',
#   'regard',
#   'fiscal',
#   'polici',
#   'govern',
#   'disrupt',
#   'credit',
#   'europ',
#   'elsewher',
#   'contract',
#   'limit',
#   'growth',
#   'consum',
#   'spend',
#   'consum',
#   'credit',
#   'advers',
#   'econom',
#   'condit',
#   'specif',
#   'internet',
#   'ecommerc',
#   'payment',
#   'industri',
#   'general',
#   'econom',
#   'condit',
#   'possibl',
#   'prolong',
#   'period',
#   'limit',
#   'econom',
#   'growth',
#   'possibl',
#   'econom',
#   'declin',
#   'europ',
#   'advers',
#   'effect',
#   'ongo',
#   'sovereign',
#   'debt',
#   'crisi',
#   'europ',
#   'increas',
#   'euro',
#   'currenc',
#   'exchang',
#   'rate',
#   'volatil',
#   'negat',
#   'impact',
#   'crisi',
#   'relat',
#   'auster',
#   'measur',
#   'european',
#   'econom',
#   'growth',
#   'potenti',
#   'negat',
#   'spillov',
#   'effect',
#   'rest',
#   'world',
#   'contagion',
#   'risk',
#   'crisi',
#   'spread',
#   'addit',
#   'countri',
#   'europ',
#   'possibl',
#   'one',
#   'countri',
#   'leav',
#   'euro',
#   'zone',
#   'introduc',
#   'individu',
#   'currenc',
#   'extrem',
#   'circumst',
#   'possibl',
#   'dissolut',
#   'euro',
#   'currenc',
#   'possibl',
#   'greater',
#   'auster',
#   'due',
#   'among',
#   'factor',
#   'automat',
#   'sequest',
#   'failur',
#   'rais',
#   'debt',
#   'ceil',
#   'relat',
#   'action',
#   'failur',
#   'take',
#   'action',
#   'congress',
#   'execut',
#   'branch',
#   'general',
#   'impact',
#   'uncertainti',
#   'regard',
#   'fiscal',
#   'polici',
#   'govern',
#   'disrupt',
#   'credit',
#   'europ',
#   'elsewher',
#   'contract',
#   'limit',
#   'growth',
#   'consum',
#   'spend',
#   'consum',
#   'credit',
#   'advers',
#   'econom',
#   'condit',
#   'specif',
#   'internet',
#   'ecommerc',
#   'payment',
#   'industri',
#   'abil',
#   'manag',
#   'rapid',
#   'shift',
#   'onlin',
#   'commerc',
#   'payment',
#   'mobil',
#   'multi',
#   'channel',
#   'commerc',
#   'payment',
#   'abil',
#   'manag',
#   'rapid',
#   'shift',
#   'onlin',
#   'commerc',
#   'payment',
#   'mobil',
#   'multi',
#   'channel',
#   'commerc',
#   'payment',
#   'abil',
#   'improv',
#   'qualiti',
#   'experi',
#   'websit',
#   'mobil',
#   'devic',
#   'custom',
#   'support',
#   'event',
#   'problem',
#   'light',
#   'improv',
#   'qualiti',
#   'general',
#   'experi',
#   'offer',
#   'competit',
#   'merchant',
#   'abil',
#   'improv',
#   'qualiti',
#   'experi',
#   'websit',
#   'mobil',
#   'devic',
#   'custom',
#   'support',
#   'event',
#   'problem',
#   'light',
#   'improv',
#   'qualiti',
#   'general',
#   'experi',
#   'offer',
#   'competit',
#   'merchant',
#   'abil',
#   'upgrad',
#   'develop',
#   'system',
#   'migrat',
#   'gsi',
#   'new',
#   'technolog',
#   'platform',
#   'need',
#   'replatform',
#   'base',
#   'paypal',
#   'technolog',
#   'infrastructur',
#   'custom',
#   'capabl',
#   'accommod',
#   'growth',
#   'improv',
#   'function',
#   'reliabl',
#   'websit',
#   'reason',
#   'maintain',
#   'abil',
#   'upgrad',
#   'develop',
#   'system',
#   'migrat',
#   'gsi',
#   'new',
#   'technolog',
#   'platform',
#   'need',
#   'replatform',
#   'base',
#   'paypal',
#   'technolog',
#   'infrastructur',
#   'custom',
#   'capabl',
#   'accommod',
#   'growth',
#   'improv',
#   'function',
#   'reliabl',
#   'websit',
#   'reason',
#   'maintain',
#   'primari',
#   'secondari',
#   'effect',
#   'previous',
#   'announc',
#   'possibl',
#   'futur',
#   'price',
#   'polici',
#   'among',
#   'restrict',
#   'hold',
#   'payment',
#   'make',
#   'certain',
#   'seller',
#   'connect',
#   'certain',
#   'transact',
#   'disput',
#   'resolut',
#   'process',
#   'upgrad',
#   'ebay',
#   'checkout',
#   'introduct',
#   'ebay',
#   'shop',
#   'cart',
#   'basket',
#   'enabl',
#   'buyer',
#   'add',
#   'item',
#   'multipl',
#   'seller',
#   'pay',
#   'singl',
#   'checkout',
#   'fee',
#   'structur',
#   'new',
#   'requir',
#   'qualifi',
#   'ebay',
#   'trust',
#   'seller',
#   'discount',
#   'design',
#   'navig',
#   'function',
#   'ebay',
#   'com',
#   'websit',
#   'redesign',
#   'homepag',
#   'new',
#   'ebay',
#   'fee',
#   'allow',
#   'establish',
#   'person',
#   'fee',
#   'item',
#   'homepag',
#   'display',
#   'larger',
#   'imag',
#   'inform',
#   'checkout',
#   'process',
#   'abil',
#   'connect',
#   'ebay',
#   'paypal',
#   'account',
#   'easili',
#   'featur',
#   'increas',
#   'intermedi',
#   'aspect',
#   'transact',
#   'buyer',
#   'seller',
#   'use',
#   'platform',
#   'primari',
#   'secondari',
#   'effect',
#   'previous',
#   'announc',
#   'possibl',
#   'futur',
#   'price',
#   'polici',
#   'among',
#   'restrict',
#   'hold',
#   'payment',
#   'make',
#   'certain',
#   'seller',
#   'connect',
#   'certain',
#   'transact',
#   'disput',
#   'resolut',
#   'process',
#   'upgrad',
#   'ebay',
#   'checkout',
#   'introduct',
#   'ebay',
#   'shop',
#   'cart',
#   'basket',
#   'enabl',
#   'buyer',
#   'add',
#   'item',
#   'multipl',
#   'seller',
#   'pay',
#   'singl',
#   'checkout',
#   'fee',
#   'structur',
#   'new',
#   'requir',
#   'qualifi',
#   'ebay',
#   'trust',
#   'seller',
#   'discount',
#   'design',
#   'navig',
#   'function',
#   'ebay',
#   'com',
#   'websit',
#   'redesign',
#   'homepag',
#   'new',
#   'ebay',
#   'fee',
#   'allow',
#   'establish',
#   'person',
#   'fee',
#   'item',
#   'homepag',
#   'display',
#   'larger',
#   'imag',
#   'inform',
#   'checkout',
#   'process',
#   'abil',
#   'connect',
#   'ebay',
#   'paypal',
#   'account',
#   'easili',
#   'featur',
#   'increas',
#   'intermedi',
#   'aspect',
#   'transact',
#   'buyer',
#   'seller',
#   'use',
#   'platform',
#   'abil',
#   'retain',
#   'activ',
#   'base',
#   'attract',
#   'new',
#   'encourag',
#   'exist',
#   'list',
#   'item',
#   'sale',
#   'purchas',
#   'item',
#   'websit',
#   'mobil',
#   'platform',
#   'use',
#   'payment',
#   'especi',
#   'consum',
#   'spend',
#   'weak',
#   'abil',
#   'retain',
#   'activ',
#   'base',
#   'attract',
#   'new',
#   'encourag',
#   'exist',
#   'list',
#   'item',
#   'sale',
#   'purchas',
#   'item',
#   'websit',
#   'mobil',
#   'platform',
#   'use',
#   'payment',
#   'especi',
#   'consum',
#   'spend',
#   'weak',
#   'consum',
#   'confid',
#   'safeti',
#   'secur',
#   'transact',
#   'use',
#   'websit',
#   'technolog',
#   'mobil',
#   'devic',
#   'effect',
#   'practic',
#   'polici',
#   'event',
#   'confid',
#   'consum',
#   'confid',
#   'safeti',
#   'secur',
#   'transact',
#   'use',
#   'websit',
#   'technolog',
#   'mobil',
#   'devic',
#   'effect',
#   'practic',
#   'polici',
#   'event',
#   'confid',
#   'abil',
#   'manag',
#   'administ',
#   'protect',
#   'program',
#   'abil',
#   'manag',
#   'administ',
#   'protect',
#   'program',
#   'abil',
#   'compli',
#   'exist',
#   'new',
#   'regul',
#   'expand',
#   'rang',
#   'geograph',
#   'scope',
#   'grow',
#   'larger',
#   'regul',
#   'discuss',
#   'caption',
#   'payment',
#   'find',
#   'subject',
#   'violat',
#   'regul',
#   'govern',
#   'money',
#   'transmiss',
#   'electron',
#   'fund',
#   'transfer',
#   'money',
#   'launder',
#   'terrorist',
#   'financ',
#   'sanction',
#   'consum',
#   'protect',
#   'bank',
#   'lend',
#   'subject',
#   'liabil',
#   'licensur',
#   'regulatori',
#   'approv',
#   'forc',
#   'practic',
#   'abil',
#   'compli',
#   'exist',
#   'new',
#   'regul',
#   'expand',
#   'rang',
#   'geograph',
#   'scope',
#   'grow',
#   'larger',
#   'regul',
#   'discuss',
#   'caption',
#   'payment',
#   'find',
#   'subject',
#   'violat',
#   'regul',
#   'govern',
#   'money',
#   'transmiss',
#   'electron',
#   'fund',
#   'transfer',
#   'money',
#   'launder',
#   'terrorist',
#   'financ',
#   'sanction',
#   'consum',
#   'protect',
#   'bank',
#   'lend',
#   'subject',
#   'liabil',
#   'licensur',
#   'regulatori',
#   'approv',
#   'forc',
#   'practic',
#   'new',
#   'regul',
#   'stem',
#   'propos',
#   'anti',
#   'counterfeit',
#   'trade',
#   'agreement',
#   'acta',
#   'tran',
#   'pacif',
#   'partnership',
#   'agreement',
#   'tpp',
#   'european',
#   'consum',
#   'right',
#   'direct',
#   'propos',
#   'new',
#   'regul',
#   'stem',
#   'propos',
#   'anti',
#   'counterfeit',
#   'trade',
#   'agreement',
#   'acta',
#   'tran',
#   'pacif',
#   'partnership',
#   'agreement',
#   'tpp',
#   'european',
#   'consum',
#   'right',
#   'direct',
#   'propos',
#   'revis',
#   'european',
#   'data',
#   'protect',
#   'direct',
#   'interpret',
#   'exist',
#   'regul',
#   'nation',
#   'court',
#   'interpret',
#   'european',
#   'court',
#   'justic',
#   'decis',
#   'ore',
#   'case',
#   'see',
#   'item',
#   'legal',
#   'proceed',
#   'impos',
#   'liabil',
#   'action',
#   'otherwis',
#   'harm',
#   'model',
#   'especi',
#   'becom',
#   'activ',
#   'involv',
#   'various',
#   'aspect',
#   'transact',
#   'platform',
#   'regulatori',
#   'legal',
#   'action',
#   'impos',
#   'oblig',
#   'injunct',
#   'relat',
#   'certain',
#   'cosmet',
#   'perfum',
#   'brand',
#   'see',
#   'item',
#   'legal',
#   'proceed',
#   'regulatori',
#   'legal',
#   'action',
#   'impos',
#   'oblig',
#   'injunct',
#   'relat',
#   'certain',
#   'cosmet',
#   'perfum',
#   'brand',
#   'see',
#   'item',
#   'legal',
#   'proceed',
#   'impact',
#   'paypal',
#   'bill',
#   'later',
#   'regul',
#   'enact',
#   'pursuant',
#   'new',
#   'regul',
#   'institut',
#   'dodd',
#   'frank',
#   'wall',
#   'street',
#   'reform',
#   'consum',
#   'protect',
#   'act',
#   'dodd',
#   'frank',
#   'act',
#   'impact',
#   'paypal',
#   'bill',
#   'later',
#   'regul',
#   'enact',
#   'pursuant',
#   'new',
#   'regul',
#   'institut',
#   'dodd',
#   'frank',
#   'wall',
#   'street',
#   'reform',
#   'consum',
#   'protect',
#   'act',
#   'dodd',
#   'frank',
#   'act',
#   'abil',
#   'manag',
#   'complianc',
#   'exist',
#   'new',
#   'regul',
#   'affect',
#   'abil',
#   'manag',
#   'complianc',
#   'exist',
#   'new',
#   'regul',
#   'affect',
#   'volum',
#   'veloc',
#   'size',
#   'time',
#   'monet',
#   'complet',
#   'rate',
#   'transact',
#   'use',
#   'websit',
#   'technolog',
#   'volum',
#   'veloc',
#   'size',
#   'time',
#   'monet',
#   'complet',
#   'rate',
#   'transact',
#   'use',
#   'websit',
#   'technolog',
#   'abil',
#   'reduc',
#   'loss',
#   'activ',
#   'buyer',
#   'seller',
#   'increas',
#   'activ',
#   'marketplac',
#   'especi',
#   'respect',
#   'top',
#   'buyer',
#   'seller',
#   'increas',
#   'activ',
#   'paypal',
#   'account',
#   'holder',
#   'particular',
#   'merchant',
#   'abil',
#   'reduc',
#   'loss',
#   'activ',
#   'buyer',
#   'seller',
#   'increas',
#   'activ',
#   'marketplac',
#   'especi',
#   'respect',
#   'top',
#   'buyer',
#   'seller',
#   'increas',
#   'activ',
#   'paypal',
#   'account',
#   'holder',
#   'particular',
#   'merchant',
#   'abil',
#   'develop',
#   'enhanc',
#   'program',
#   'featur',
#   'differ',
#   'platform',
#   'mobil',
#   'devic',
#   'reason',
#   'time',
#   'manner',
#   'initi',
#   'make',
#   'paypal',
#   'solut',
#   'avail',
#   'retail',
#   'point',
#   'sale',
#   'abil',
#   'develop',
#   'enhanc',
#   'program',
#   'featur',
#   'differ',
#   'platform',
#   'mobil',
#   'devic',
#   'reason',
#   'time',
#   'manner',
#   'initi',
#   'make',
#   'paypal',
#   'solut',
#   'avail',
#   'retail',
#   'point',
#   'sale',
#   'use',
#   'advertis',
#   'site',
#   'use',
#   'advertis',
#   'site',
#   'action',
#   'competitor',
#   'introduct',
#   'new',
#   'store',
#   'channel',
#   'site',
#   'applic',
#   'function',
#   'provis',
#   'import',
#   'success',
#   'internet',
#   'search',
#   'access',
#   'smartphon',
#   'oper',
#   'system',
#   'action',
#   'competitor',
#   'introduct',
#   'new',
#   ...],
#  ['risk',
#   'factor',
#   'affect',
#   'condit',
#   'oper',
#   'subject',
#   'various',
#   'risk',
#   'uncertainti',
#   'advers',
#   'affect',
#   'condit',
#   'flow',
#   'well',
#   'trade',
#   'price',
#   'common',
#   'stock',
#   'debt',
#   'secur',
#   'oper',
#   'vari',
#   'quarter',
#   'basi',
#   'oper',
#   'histori',
#   'oper',
#   'fluctuat',
#   'signific',
#   'varieti',
#   'factor',
#   'mani',
#   'outsid',
#   'control',
#   'factor',
#   'affect',
#   'oper',
#   'risk',
#   'describ',
#   'elsewher',
#   'section',
#   'follow',
#   'general',
#   'econom',
#   'condit',
#   'possibl',
#   'prolong',
#   'period',
#   'limit',
#   'econom',
#   'growth',
#   'possibl',
#   'econom',
#   'declin',
#   'europ',
#   'advers',
#   'effect',
#   'ongo',
#   'sovereign',
#   'debt',
#   'crisi',
#   'europ',
#   'increas',
#   'euro',
#   'currenc',
#   'exchang',
#   'rate',
#   'volatil',
#   'negat',
#   'impact',
#   'crisi',
#   'relat',
#   'auster',
#   'measur',
#   'european',
#   'econom',
#   'growth',
#   'potenti',
#   'negat',
#   'spillov',
#   'effect',
#   'rest',
#   'world',
#   'contagion',
#   'risk',
#   'crisi',
#   'spread',
#   'addit',
#   'countri',
#   'europ',
#   'possibl',
#   'one',
#   'countri',
#   'leav',
#   'euro',
#   'zone',
#   'introduc',
#   'individu',
#   'currenc',
#   'extrem',
#   'circumst',
#   'possibl',
#   'dissolut',
#   'euro',
#   'currenc',
#   'possibl',
#   'greater',
#   'auster',
#   'due',
#   'among',
#   'factor',
#   'potenti',
#   'shutdown',
#   'govern',
#   'potenti',
#   'failur',
#   'rais',
#   'debt',
#   'ceil',
#   'automat',
#   'sequest',
#   'relat',
#   'action',
#   'failur',
#   'take',
#   'action',
#   'congress',
#   'execut',
#   'branch',
#   'general',
#   'impact',
#   'uncertainti',
#   'regard',
#   'fiscal',
#   'polici',
#   'govern',
#   'disrupt',
#   'credit',
#   'europ',
#   'elsewher',
#   'contract',
#   'limit',
#   'growth',
#   'consum',
#   'spend',
#   'consum',
#   'credit',
#   'advers',
#   'econom',
#   'condit',
#   'specif',
#   'internet',
#   'ecommerc',
#   'payment',
#   'industri',
#   'general',
#   'econom',
#   'condit',
#   'possibl',
#   'prolong',
#   'period',
#   'limit',
#   'econom',
#   'growth',
#   'possibl',
#   'econom',
#   'declin',
#   'europ',
#   'advers',
#   'effect',
#   'ongo',
#   'sovereign',
#   'debt',
#   'crisi',
#   'europ',
#   'increas',
#   'euro',
#   'currenc',
#   'exchang',
#   'rate',
#   'volatil',
#   'negat',
#   'impact',
#   'crisi',
#   'relat',
#   'auster',
#   'measur',
#   'european',
#   'econom',
#   'growth',
#   'potenti',
#   'negat',
#   'spillov',
#   'effect',
#   'rest',
#   'world',
#   'contagion',
#   'risk',
#   'crisi',
#   'spread',
#   'addit',
#   'countri',
#   'europ',
#   'possibl',
#   'one',
#   'countri',
#   'leav',
#   'euro',
#   'zone',
#   'introduc',
#   'individu',
#   'currenc',
#   'extrem',
#   'circumst',
#   'possibl',
#   'dissolut',
#   'euro',
#   'currenc',
#   'possibl',
#   'greater',
#   'auster',
#   'due',
#   'among',
#   'factor',
#   'potenti',
#   'shutdown',
#   'govern',
#   'potenti',
#   'failur',
#   'rais',
#   'debt',
#   'ceil',
#   'automat',
#   'sequest',
#   'relat',
#   'action',
#   'failur',
#   'take',
#   'action',
#   'congress',
#   'execut',
#   'branch',
#   'general',
#   'impact',
#   'uncertainti',
#   'regard',
#   'fiscal',
#   'polici',
#   'govern',
#   'disrupt',
#   'credit',
#   'europ',
#   'elsewher',
#   'contract',
#   'limit',
#   'growth',
#   'consum',
#   'spend',
#   'consum',
#   'credit',
#   'advers',
#   'econom',
#   'condit',
#   'specif',
#   'internet',
#   'ecommerc',
#   'payment',
#   'industri',
#   'abil',
#   'manag',
#   'rapid',
#   'shift',
#   'onlin',
#   'commerc',
#   'payment',
#   'mobil',
#   'multi',
#   'channel',
#   'commerc',
#   'payment',
#   'abil',
#   'manag',
#   'rapid',
#   'shift',
#   'onlin',
#   'commerc',
#   'payment',
#   'mobil',
#   'multi',
#   'channel',
#   'commerc',
#   'payment',
#   'abil',
#   'improv',
#   'qualiti',
#   'experi',
#   'websit',
#   'mobil',
#   'devic',
#   'custom',
#   'support',
#   'event',
#   'problem',
#   'keep',
#   'pace',
#   'improv',
#   'qualiti',
#   'experi',
#   'general',
#   'offer',
#   'competit',
#   'platform',
#   'abil',
#   'improv',
#   'qualiti',
#   'experi',
#   'websit',
#   'mobil',
#   'devic',
#   'custom',
#   'support',
#   'event',
#   'problem',
#   'keep',
#   'pace',
#   'improv',
#   'qualiti',
#   'experi',
#   'general',
#   'offer',
#   'competit',
#   'platform',
#   'abil',
#   'upgrad',
#   'develop',
#   'system',
#   'migrat',
#   'enterpris',
#   'new',
#   'enterpris',
#   'commerc',
#   'platform',
#   'replatform',
#   'base',
#   'paypal',
#   'technolog',
#   'infrastructur',
#   'custom',
#   'capabl',
#   'accommod',
#   'growth',
#   'improv',
#   'function',
#   'reliabl',
#   'websit',
#   'mobil',
#   'platform',
#   'reason',
#   'maintain',
#   'abil',
#   'upgrad',
#   'develop',
#   'system',
#   'migrat',
#   'enterpris',
#   'new',
#   'enterpris',
#   'commerc',
#   'platform',
#   'replatform',
#   'base',
#   'paypal',
#   'technolog',
#   'infrastructur',
#   'custom',
#   'capabl',
#   'accommod',
#   'growth',
#   'improv',
#   'function',
#   'reliabl',
#   'websit',
#   'mobil',
#   'platform',
#   'reason',
#   'maintain',
#   'primari',
#   'secondari',
#   'effect',
#   'previous',
#   'announc',
#   'possibl',
#   'futur',
#   'price',
#   'polici',
#   'among',
#   'restrict',
#   'hold',
#   'payment',
#   'make',
#   'certain',
#   'seller',
#   'connect',
#   'certain',
#   'transact',
#   'fee',
#   'structur',
#   'checkout',
#   'process',
#   'ebay',
#   'shop',
#   'cart',
#   'basket',
#   'abil',
#   'connect',
#   'ebay',
#   'paypal',
#   'account',
#   'easili',
#   'new',
#   'function',
#   'seller',
#   'specifi',
#   'ship',
#   'payment',
#   'return',
#   'polici',
#   'collect',
#   'refer',
#   'polici',
#   'seller',
#   'automat',
#   'begin',
#   'opt',
#   'begin',
#   'august',
#   'becom',
#   'mandatori',
#   'enforc',
#   'new',
#   'pictur',
#   'qualiti',
#   'requir',
#   'list',
#   'item',
#   'start',
#   'juli',
#   'automat',
#   'enrol',
#   'new',
#   'seller',
#   'autom',
#   'ebay',
#   'return',
#   'process',
#   'featur',
#   'increas',
#   'intermedi',
#   'aspect',
#   'transact',
#   'buyer',
#   'seller',
#   'use',
#   'platform',
#   'primari',
#   'secondari',
#   'effect',
#   'previous',
#   'announc',
#   'possibl',
#   'futur',
#   'price',
#   'polici',
#   'among',
#   'restrict',
#   'hold',
#   'payment',
#   'make',
#   'certain',
#   'seller',
#   'connect',
#   'certain',
#   'transact',
#   'fee',
#   'structur',
#   'checkout',
#   'process',
#   'ebay',
#   'shop',
#   'cart',
#   'basket',
#   'abil',
#   'connect',
#   'ebay',
#   'paypal',
#   'account',
#   'easili',
#   'new',
#   'function',
#   'seller',
#   'specifi',
#   'ship',
#   'payment',
#   'return',
#   'polici',
#   'collect',
#   'refer',
#   'polici',
#   'seller',
#   'automat',
#   'begin',
#   'opt',
#   'begin',
#   'august',
#   'becom',
#   'mandatori',
#   'enforc',
#   'new',
#   'pictur',
#   'qualiti',
#   'requir',
#   'list',
#   'item',
#   'start',
#   'juli',
#   'automat',
#   'enrol',
#   'new',
#   'seller',
#   'autom',
#   'ebay',
#   'return',
#   'process',
#   'featur',
#   'increas',
#   'intermedi',
#   'aspect',
#   'transact',
#   'buyer',
#   'seller',
#   'use',
#   'platform',
#   'abil',
#   'retain',
#   'activ',
#   'base',
#   'attract',
#   'new',
#   'encourag',
#   'exist',
#   'list',
#   'item',
#   'sale',
#   'purchas',
#   'item',
#   'websit',
#   'mobil',
#   'platform',
#   'use',
#   'payment',
#   'especi',
#   'face',
#   'improv',
#   'competitor',
#   'platform',
#   'abil',
#   'retain',
#   'activ',
#   'base',
#   'attract',
#   'new',
#   'encourag',
#   'exist',
#   'list',
#   'item',
#   'sale',
#   'purchas',
#   'item',
#   'websit',
#   'mobil',
#   'platform',
#   'use',
#   'payment',
#   'especi',
#   'face',
#   'improv',
#   'competitor',
#   'platform',
#   'consum',
#   'confid',
#   'safeti',
#   'secur',
#   'transact',
#   'use',
#   'websit',
#   'technolog',
#   'mobil',
#   'devic',
#   'effect',
#   'practic',
#   'polici',
#   'event',
#   'confid',
#   'consum',
#   'confid',
#   'safeti',
#   'secur',
#   'transact',
#   'use',
#   'websit',
#   'technolog',
#   'mobil',
#   'devic',
#   'effect',
#   'practic',
#   'polici',
#   'event',
#   'confid',
#   'action',
#   'competitor',
#   'introduct',
#   'new',
#   'store',
#   'channel',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'function',
#   'provis',
#   'price',
#   'import',
#   'success',
#   'interchang',
#   'internet',
#   'search',
#   'mobil',
#   'oper',
#   'system',
#   'action',
#   'competitor',
#   'introduct',
#   'new',
#   'store',
#   'channel',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'function',
#   'provis',
#   'price',
#   'import',
#   'success',
#   'interchang',
#   'internet',
#   'search',
#   'mobil',
#   'oper',
#   'system',
#   'abil',
#   'effect',
#   'manag',
#   'administ',
#   'protect',
#   'program',
#   'abil',
#   'effect',
#   'manag',
#   'administ',
#   'protect',
#   'program',
#   'impact',
#   'paypal',
#   'bill',
#   'later',
#   'regul',
#   'enact',
#   'pursuant',
#   'new',
#   'regul',
#   'institut',
#   'dodd',
#   'frank',
#   'wall',
#   'street',
#   'reform',
#   'consum',
#   'protect',
#   'act',
#   'dodd',
#   'frank',
#   'act',
#   'impact',
#   'paypal',
#   'bill',
#   'later',
#   'regul',
#   'enact',
#   'pursuant',
#   'new',
#   'regul',
#   'institut',
#   'dodd',
#   'frank',
#   'wall',
#   'street',
#   'reform',
#   'consum',
#   'protect',
#   'act',
#   'dodd',
#   'frank',
#   'act',
#   'abil',
#   'compli',
#   'exist',
#   'new',
#   'regul',
#   'expand',
#   'rang',
#   'geograph',
#   'scope',
#   'grow',
#   'larger',
#   'regul',
#   'discuss',
#   'caption',
#   'mani',
#   'risk',
#   'associ',
#   'intern',
#   'subject',
#   'general',
#   'litig',
#   'regulatori',
#   'disput',
#   'payment',
#   'subject',
#   'number',
#   'regul',
#   'govern',
#   'bank',
#   'cross',
#   'border',
#   'domest',
#   'money',
#   'transmiss',
#   'foreign',
#   'exchang',
#   'payment',
#   'vari',
#   'oper',
#   'payment',
#   'subject',
#   'anti',
#   'money',
#   'launder',
#   'counter',
#   'abil',
#   'compli',
#   'exist',
#   'new',
#   'regul',
#   'expand',
#   'rang',
#   'geograph',
#   'scope',
#   'grow',
#   'larger',
#   'regul',
#   'discuss',
#   'caption',
#   'mani',
#   'risk',
#   'associ',
#   'intern',
#   'subject',
#   'general',
#   'litig',
#   'regulatori',
#   'disput',
#   'payment',
#   'subject',
#   'number',
#   'regul',
#   'govern',
#   'bank',
#   'cross',
#   'border',
#   'domest',
#   'money',
#   'transmiss',
#   'foreign',
#   'exchang',
#   'payment',
#   'vari',
#   'oper',
#   'payment',
#   'subject',
#   'anti',
#   'money',
#   'launder',
#   'counter',
#   'terrorist',
#   'financ',
#   'regul',
#   'payment',
#   'subject',
#   'consum',
#   'protect',
#   'regul',
#   'new',
#   'regul',
#   'stem',
#   'propos',
#   'anti',
#   'counterfeit',
#   'trade',
#   'agreement',
#   'acta',
#   'tran',
#   'pacif',
#   'partnership',
#   'agreement',
#   'tpp',
#   'european',
#   'consum',
#   'right',
#   'direct',
#   'propos',
#   'revis',
#   'european',
#   'data',
#   'protect',
#   'direct',
#   'interpret',
#   'exist',
#   'regul',
#   'nation',
#   'court',
#   'interpret',
#   'european',
#   'court',
#   'justic',
#   'decis',
#   'ore',
#   'case',
#   'see',
#   'item',
#   'legal',
#   'proceed',
#   'impos',
#   'liabil',
#   'action',
#   'otherwis',
#   'harm',
#   'model',
#   'especi',
#   'becom',
#   'activ',
#   'involv',
#   'various',
#   'aspect',
#   'transact',
#   'platform',
#   'new',
#   'regul',
#   'stem',
#   'propos',
#   'anti',
#   'counterfeit',
#   'trade',
#   'agreement',
#   'acta',
#   'tran',
#   'pacif',
#   'partnership',
#   'agreement',
#   'tpp',
#   'european',
#   'consum',
#   'right',
#   'direct',
#   'propos',
#   'revis',
#   'european',
#   'data',
#   'protect',
#   'direct',
#   'interpret',
#   'exist',
#   'regul',
#   'nation',
#   'court',
#   'interpret',
#   'european',
#   'court',
#   'justic',
#   'decis',
#   'ore',
#   'case',
#   'see',
#   'item',
#   'legal',
#   'proceed',
#   'impos',
#   'liabil',
#   'action',
#   'otherwis',
#   'harm',
#   'model',
#   'especi',
#   'becom',
#   'activ',
#   'involv',
#   'various',
#   'aspect',
#   'transact',
#   'platform',
#   'regulatori',
#   'legal',
#   'action',
#   'impos',
#   'oblig',
#   'injunct',
#   'relat',
#   'certain',
#   'cosmet',
#   'perfum',
#   'brand',
#   'see',
#   'item',
#   'legal',
#   'proceed',
#   'regulatori',
#   'legal',
#   'action',
#   'impos',
#   'oblig',
#   'injunct',
#   'relat',
#   'certain',
#   'cosmet',
#   'perfum',
#   'brand',
#   'see',
#   'item',
#   'legal',
#   'proceed',
#   'abil',
#   'manag',
#   'complianc',
#   'exist',
#   'new',
#   'regul',
#   'affect',
#   'abil',
#   'manag',
#   'complianc',
#   'exist',
#   'new',
#   'regul',
#   'affect',
#   'new',
#   'regul',
#   'particular',
#   'privaci',
#   'regul',
#   'enact',
#   'jurisdict',
#   'data',
#   'custom',
#   'inform',
#   'transact',
#   'data',
#   'inform',
#   'store',
#   'local',
#   'server',
#   'jurisdict',
#   'prohibit',
#   'data',
#   'transmit',
#   'outsid',
#   'jurisdict',
#   'would',
#   'increas',
#   'oper',
#   'capit',
#   'expenditur',
#   'potenti',
#   'impact',
#   'perform',
#   'avail',
#   'abil',
#   'use',
#   'process',
#   'custom',
#   'data',
#   ...],
#  ['follow',
#   'discuss',
#   'divid',
#   'two',
#   'section',
#   'first',
#   'section',
#   'begin',
#   'immedi',
#   'follow',
#   'paragraph',
#   'discus',
#   'risk',
#   'affect',
#   'condit',
#   'second',
#   'section',
#   'caption',
#   'risk',
#   'factor',
#   'relat',
#   'separ',
#   'discus',
#   'risk',
#   'relat',
#   'separ',
#   'paypal',
#   'independ',
#   'public',
#   'trade',
#   'care',
#   'review',
#   'section',
#   'well',
#   'consolid',
#   'statement',
#   'note',
#   'inform',
#   'appear',
#   'report',
#   'import',
#   'inform',
#   'regard',
#   'risk',
#   'affect',
#   'risk',
#   'factor',
#   'affect',
#   'condit',
#   'oper',
#   'subject',
#   'various',
#   'risk',
#   'uncertainti',
#   'advers',
#   'affect',
#   'condit',
#   'flow',
#   'well',
#   'trade',
#   'price',
#   'common',
#   'stock',
#   'debt',
#   'secur',
#   'oper',
#   'vari',
#   'quarter',
#   'basi',
#   'oper',
#   'histori',
#   'continu',
#   'fluctuat',
#   'signific',
#   'varieti',
#   'factor',
#   'risk',
#   'set',
#   'forth',
#   'risk',
#   'factor',
#   'section',
#   'difficult',
#   'forecast',
#   'level',
#   'sourc',
#   'revenu',
#   'earn',
#   'loss',
#   'accur',
#   'view',
#   'rapid',
#   'evolv',
#   'natur',
#   'period',
#   'period',
#   'comparison',
#   'oper',
#   'meaning',
#   'reli',
#   'upon',
#   'indic',
#   'futur',
#   'perform',
#   'backlog',
#   'substanti',
#   'net',
#   'revenu',
#   'quarter',
#   'come',
#   'transact',
#   'involv',
#   'sale',
#   'payment',
#   'quarter',
#   'due',
#   'inher',
#   'difficulti',
#   'forecast',
#   'revenu',
#   'difficult',
#   'forecast',
#   'expens',
#   'percentag',
#   'net',
#   'revenu',
#   'quarter',
#   'annual',
#   'expens',
#   'percentag',
#   'net',
#   'revenu',
#   'reflect',
#   'consolid',
#   'statement',
#   'signific',
#   'differ',
#   'histor',
#   'project',
#   'rate',
#   'oper',
#   'one',
#   'futur',
#   'quarter',
#   'fall',
#   'expect',
#   'secur',
#   'analyst',
#   'investor',
#   'trade',
#   'price',
#   'common',
#   'stock',
#   'debt',
#   'secur',
#   'declin',
#   'perhap',
#   'substanti',
#   'factor',
#   'describ',
#   'paragraph',
#   'substanti',
#   'increas',
#   'intens',
#   'competit',
#   'worldwid',
#   'ecommerc',
#   'global',
#   'payment',
#   'industri',
#   'materi',
#   'advers',
#   'affect',
#   'overal',
#   'marketplac',
#   'current',
#   'potenti',
#   'compet',
#   'wide',
#   'varieti',
#   'onlin',
#   'offlin',
#   'provid',
#   'good',
#   'consum',
#   'merchant',
#   'internet',
#   'mobil',
#   'network',
#   'provid',
#   'new',
#   'rapid',
#   'evolv',
#   'intens',
#   'competit',
#   'channel',
#   'sale',
#   'type',
#   'good',
#   'marketplac',
#   'compet',
#   'two',
#   'side',
#   'must',
#   'attract',
#   'buyer',
#   'seller',
#   'use',
#   'platform',
#   'consum',
#   'purchas',
#   'sell',
#   'good',
#   'marketplac',
#   'altern',
#   'merchant',
#   'channel',
#   'reach',
#   'consum',
#   'expect',
#   'competit',
#   'continu',
#   'intensifi',
#   'onlin',
#   'offlin',
#   'increas',
#   'compet',
#   'competitor',
#   'number',
#   'onlin',
#   'offlin',
#   'retail',
#   'signific',
#   'resourc',
#   'well',
#   'establish',
#   'brand',
#   'moreov',
#   'barrier',
#   'entri',
#   'channel',
#   'low',
#   'easili',
#   'launch',
#   'onlin',
#   'site',
#   'mobil',
#   'platform',
#   'applic',
#   'nomin',
#   'use',
#   'commerci',
#   'avail',
#   'softwar',
#   'partner',
#   'number',
#   'success',
#   'ecommerc',
#   'respond',
#   'competit',
#   'environ',
#   'time',
#   'time',
#   'make',
#   'price',
#   'decis',
#   'acquisit',
#   'controversi',
#   'lead',
#   'dissatisfact',
#   'among',
#   'seller',
#   'reduc',
#   'activ',
#   'websit',
#   'harm',
#   'profit',
#   'marketplac',
#   'face',
#   'increas',
#   'competit',
#   'pressur',
#   'onlin',
#   'offlin',
#   'particular',
#   'competit',
#   'norm',
#   'expect',
#   'level',
#   'ecommerc',
#   'mobil',
#   'commerc',
#   'signific',
#   'increas',
#   'due',
#   'among',
#   'factor',
#   'improv',
#   'experi',
#   'greater',
#   'eas',
#   'buy',
#   'good',
#   'lower',
#   'ship',
#   'faster',
#   'ship',
#   'time',
#   'favor',
#   'return',
#   'polici',
#   'certain',
#   'platform',
#   'alibaba',
#   'appl',
#   'googl',
#   'facebook',
#   'mani',
#   'larger',
#   'greater',
#   'capit',
#   'domin',
#   'secur',
#   'posit',
#   'industri',
#   'certain',
#   'signific',
#   'offer',
#   'good',
#   'consum',
#   'merchant',
#   'offer',
#   'unabl',
#   'offer',
#   'way',
#   'reflect',
#   'demand',
#   'ecommerc',
#   'mobil',
#   'commerc',
#   'marketplac',
#   'particular',
#   'higher',
#   'growth',
#   'sale',
#   'fix',
#   'price',
#   'item',
#   'higher',
#   'expect',
#   'level',
#   'depend',
#   'provid',
#   'seller',
#   'platform',
#   'compet',
#   'effect',
#   'adapt',
#   'larger',
#   'platform',
#   'suffer',
#   'competitor',
#   'revenu',
#   'sourc',
#   'abl',
#   'devot',
#   'resourc',
#   'promot',
#   'campaign',
#   'adopt',
#   'aggress',
#   'price',
#   'polici',
#   'devot',
#   'resourc',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'system',
#   'develop',
#   'competitor',
#   'offer',
#   'continu',
#   'offer',
#   'faster',
#   'free',
#   'ship',
#   'deliveri',
#   'sunday',
#   'day',
#   'deliveri',
#   'favor',
#   'return',
#   'polici',
#   'transact',
#   'relat',
#   'improv',
#   'experi',
#   'site',
#   'impract',
#   'ineffici',
#   'seller',
#   'match',
#   'competitor',
#   'abl',
#   'innov',
#   'faster',
#   'effici',
#   'new',
#   'technolog',
#   'increas',
#   'competit',
#   'pressur',
#   'enabl',
#   'competitor',
#   'offer',
#   'effici',
#   'lower',
#   'competitor',
#   'control',
#   'import',
#   'success',
#   'credit',
#   'card',
#   'interchang',
#   'internet',
#   'search',
#   'mobil',
#   'oper',
#   'system',
#   'competitor',
#   'manipul',
#   'price',
#   'avail',
#   'term',
#   'relat',
#   'manner',
#   'impact',
#   'competit',
#   'offer',
#   'exampl',
#   'googl',
#   'oper',
#   'shop',
#   'platform',
#   'make',
#   'search',
#   'algorithm',
#   'reduc',
#   'amount',
#   'search',
#   'traffic',
#   'direct',
#   'marketplac',
#   'search',
#   'googl',
#   'unabl',
#   'use',
#   'adapt',
#   'oper',
#   'face',
#   'higher',
#   'face',
#   'integr',
#   'technolog',
#   'barrier',
#   'rais',
#   'suffer',
#   'consum',
#   'might',
#   'use',
#   'marketplac',
#   'site',
#   'buy',
#   'good',
#   'wide',
#   'varieti',
#   'altern',
#   'tradit',
#   'depart',
#   'warehous',
#   'boutiqu',
#   'discount',
#   'general',
#   'merchandis',
#   'store',
#   'well',
#   'onlin',
#   'mobil',
#   'tradit',
#   'retail',
#   'onlin',
#   'retail',
#   'relat',
#   'mobil',
#   'offer',
#   'onlin',
#   'offlin',
#   'classifi',
#   'shop',
#   'channel',
#   'offlin',
#   'onlin',
#   'home',
#   'shop',
#   'network',
#   'unit',
#   'state',
#   'amazon',
#   'com',
#   'recent',
#   'open',
#   'experiment',
#   'brick',
#   'mortar',
#   'store',
#   'new',
#   'york',
#   'citi',
#   'continu',
#   'expand',
#   'new',
#   'geographi',
#   'line',
#   'googl',
#   'wal',
#   'mart',
#   'target',
#   'sear',
#   'maci',
#   'penney',
#   'costco',
#   'offic',
#   'depot',
#   'stapl',
#   'officemax',
#   'sam',
#   'club',
#   'buy',
#   'com',
#   'rakuten',
#   'yahoo',
#   'shop',
#   'msn',
#   'qvc',
#   'home',
#   'shop',
#   'network',
#   'among',
#   'other',
#   'addit',
#   'consum',
#   'larg',
#   'number',
#   'onlin',
#   'offlin',
#   'channel',
#   'focus',
#   'one',
#   'categori',
#   'offer',
#   'site',
#   'consum',
#   'turn',
#   'mani',
#   'offer',
#   'varieti',
#   'provid',
#   'channel',
#   'buyer',
#   'find',
#   'buy',
#   'item',
#   'seller',
#   'size',
#   'onlin',
#   'aggreg',
#   'classifi',
#   'websit',
#   'craigslist',
#   'minor',
#   'equiti',
#   'stake',
#   'oodl',
#   'com',
#   'number',
#   'intern',
#   'websit',
#   'oper',
#   'schibst',
#   'asa',
#   'nasper',
#   'limit',
#   'consum',
#   'turn',
#   'shop',
#   'comparison',
#   'site',
#   'googl',
#   'shop',
#   'certain',
#   'fix',
#   'price',
#   'list',
#   'tradit',
#   'auction',
#   'style',
#   'list',
#   'format',
#   'increas',
#   'challeng',
#   'format',
#   'classifi',
#   'classifi',
#   'websit',
#   'offer',
#   'classifi',
#   'list',
#   'unit',
#   'state',
#   'varieti',
#   'local',
#   'intern',
#   'mani',
#   'oper',
#   'unit',
#   'state',
#   'classifi',
#   'platform',
#   'compet',
#   'custom',
#   'advertis',
#   'establish',
#   'onlin',
#   'offlin',
#   'classifi',
#   'platform',
#   'onlin',
#   'shop',
#   'comparison',
#   'websit',
#   'shop',
#   'com',
#   'compet',
#   'site',
#   'googl',
#   'shop',
#   'buy',
#   'com',
#   'nextag',
#   'com',
#   'pricegrabb',
#   'com',
#   'shopzilla',
#   'buscap',
#   'latin',
#   'america',
#   'nasper',
#   'yahoo',
#   'search',
#   'offer',
#   'shop',
#   'search',
#   'engin',
#   'allow',
#   'consum',
#   'search',
#   'internet',
#   'specifi',
#   'addit',
#   'seller',
#   'increas',
#   'util',
#   'multipl',
#   'sale',
#   'channel',
#   'acquisit',
#   'new',
#   'custom',
#   'pay',
#   'search',
#   'relat',
#   'advertis',
#   'horizont',
#   'search',
#   'engin',
#   'site',
#   'googl',
#   'yahoo',
#   'naver',
#   'baidu',
#   'use',
#   'search',
#   'engin',
#   'pay',
#   'search',
#   'advertis',
#   'help',
#   'find',
#   'site',
#   'potenti',
#   'divert',
#   'onlin',
#   'shop',
#   'destin',
#   'consum',
#   'choos',
#   'search',
#   'horizont',
#   'search',
#   'engin',
#   'shop',
#   'comparison',
#   'websit',
#   'site',
#   'send',
#   'shop',
#   'destin',
#   'consum',
#   'merchant',
#   'might',
#   'use',
#   'site',
#   'sell',
#   'good',
#   'mani',
#   'altern',
#   'general',
#   'onlin',
#   'ecommerc',
#   'site',
#   'amazon',
#   'alibaba',
#   'special',
#   'site',
#   'etsi',
#   'intern',
#   'site',
#   'compet',
#   'seller',
#   'general',
#   'special',
#   'onlin',
#   'ecommerc',
#   'site',
#   'seller',
#   'choos',
#   'sell',
#   'good',
#   'channel',
#   'classifi',
#   'site',
#   'consum',
#   'merchant',
#   'creat',
#   'sell',
#   'site',
#   'choos',
#   'purchas',
#   'onlin',
#   'advertis',
#   'instead',
#   'use',
#   'countri',
#   'onlin',
#   'site',
#   'larger',
#   'custom',
#   'base',
#   'greater',
#   'brand',
#   'recognit',
#   'well',
#   'competitor',
#   'better',
#   'understand',
#   'local',
#   'cultur',
#   'commerc',
#   'increas',
#   'compet',
#   'local',
#   'competitor',
#   'develop',
#   'countri',
#   'uniqu',
#   'advantag',
#   'greater',
#   'abil',
#   'oper',
#   'local',
#   'regulatori',
#   'author',
#   'addit',
#   'certain',
#   'manufactur',
#   'limit',
#   'ceas',
#   'distribut',
#   'onlin',
#   'channel',
#   'marketplac',
#   'site',
#   'manufactur',
#   'attempt',
#   'use',
#   'contractu',
#   'oblig',
#   'exist',
#   'futur',
#   'govern',
#   'regul',
#   'prohibit',
#   'limit',
#   'ecommerc',
#   'certain',
#   'categori',
#   'good',
#   'manufactur',
#   'attempt',
#   'enforc',
#   'minimum',
#   'resal',
#   'price',
#   'mainten',
#   'minimum',
#   'advertis',
#   'price',
#   'arrang',
#   'prevent',
#   'distributor',
#   'sell',
#   'websit',
#   'internet',
#   'general',
#   'price',
#   'would',
#   'make',
#   'attract',
#   'relat',
#   'altern',
#   'adopt',
#   'manufactur',
#   'polici',
#   'use',
#   'regul',
#   'case',
#   'discourag',
#   'restrict',
#   'sale',
#   'good',
#   'internet',
#   'forc',
#   'stop',
#   'sell',
#   'certain',
#   'websit',
#   'reduc',
#   'oper',
#   'margin',
#   'loss',
#   'share',
#   'diminish',
#   'valu',
#   'brand',
#   'princip',
#   'competit',
#   'factor',
#   'marketplac',
#   'follow',
#   'abil',
#   'attract',
#   'retain',
#   'engag',
#   'buyer',
#   'seller',
#   'engag',
#   'abil',
#   'attract',
#   'retain',
#   'engag',
#   'buyer',
#   'seller',
#   'engag',
#   'volum',
#   'transact',
#   'price',
#   'select',
#   'good',
#   'volum',
#   'transact',
#   'price',
#   'select',
#   'good',
#   'trust',
#   'seller',
#   'transact',
#   'trust',
#   'seller',
#   'transact',
#   'communiti',
#   'cohes',
#   'interact',
#   'size',
#   'communiti',
#   'cohes',
#   'interact',
#   'size',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'eas',
#   'use',
#   'access',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'eas',
#   'use',
#   'access',
#   'reliabl',
#   'deliveri',
#   'payment',
#   'custom',
#   'prefer',
#   'fast',
#   'deliveri',
#   'free',
#   'ship',
#   'return',
#   'reliabl',
#   'deliveri',
#   'payment',
#   'custom',
#   'prefer',
#   'fast',
#   'deliveri',
#   'free',
#   'ship',
#   'return',
#   'level',
#   'fee',
#   'level',
#   'fee',
#   'qualiti',
#   'search',
#   'tool',
#   'qualiti',
#   'search',
#   'tool',
#   'unabl',
#   'compet',
#   'success',
#   'current',
#   'futur',
#   'competitor',
#   'current',
#   'potenti',
#   'competitor',
#   'longer',
#   'oper',
#   'histori',
#   'larger',
#   'custom',
#   'base',
#   'greater',
#   'brand',
#   'recognit',
#   'internet',
#   'sector',
#   'global',
#   'payment',
#   'industri',
#   'high',
#   'competit',
#   'compet',
#   'vari',
#   'industri',
#   'mani',
#   'larger',
#   'domin',
#   'secur',
#   'posit',
#   'industri',
#   'offer',
#   'good',
#   'consum',
#   'merchant',
#   'offer',
#   'onlin',
#   'offlin',
#   'commerc',
#   'increas',
#   'converg',
#   'pace',
#   'innov',
#   'disrupt',
#   ...],
#  ['care',
#   'review',
#   'follow',
#   'discuss',
#   'risk',
#   'affect',
#   'condit',
#   'well',
#   'consolid',
#   'statement',
#   'note',
#   'inform',
#   'appear',
#   'report',
#   'import',
#   'inform',
#   'regard',
#   'risk',
#   'affect',
#   'risk',
#   'factor',
#   'affect',
#   'condit',
#   'oper',
#   'subject',
#   'various',
#   'risk',
#   'uncertainti',
#   'advers',
#   'affect',
#   'condit',
#   'flow',
#   'well',
#   'trade',
#   'price',
#   'common',
#   'stock',
#   'debt',
#   'secur',
#   'oper',
#   'vari',
#   'quarter',
#   'basi',
#   'oper',
#   'histori',
#   'continu',
#   'fluctuat',
#   'signific',
#   'varieti',
#   'factor',
#   'risk',
#   'set',
#   'forth',
#   'risk',
#   'factor',
#   'section',
#   'difficult',
#   'forecast',
#   'level',
#   'sourc',
#   'revenu',
#   'earn',
#   'loss',
#   'accur',
#   'view',
#   'rapid',
#   'evolv',
#   'natur',
#   'period',
#   'period',
#   'comparison',
#   'oper',
#   'meaning',
#   'reli',
#   'upon',
#   'indic',
#   'futur',
#   'perform',
#   'backlog',
#   'substanti',
#   'net',
#   'revenu',
#   'quarter',
#   'come',
#   'transact',
#   'involv',
#   'sale',
#   'quarter',
#   'due',
#   'inher',
#   'difficulti',
#   'forecast',
#   'revenu',
#   'difficult',
#   'forecast',
#   'expens',
#   'percentag',
#   'net',
#   'revenu',
#   'quarter',
#   'annual',
#   'expens',
#   'percentag',
#   'net',
#   'revenu',
#   'reflect',
#   'consolid',
#   'statement',
#   'signific',
#   'differ',
#   'histor',
#   'project',
#   'rate',
#   'oper',
#   'one',
#   'futur',
#   'quarter',
#   'fall',
#   'expect',
#   'secur',
#   'analyst',
#   'investor',
#   'trade',
#   'price',
#   'common',
#   'stock',
#   'debt',
#   'secur',
#   'declin',
#   'perhap',
#   'substanti',
#   'factor',
#   'describ',
#   'paragraph',
#   'substanti',
#   'increas',
#   'intens',
#   'competit',
#   'worldwid',
#   'ecommerc',
#   'harm',
#   'oper',
#   'intens',
#   'competit',
#   'current',
#   'potenti',
#   'compet',
#   'wide',
#   'varieti',
#   'onlin',
#   'offlin',
#   'provid',
#   'good',
#   'consum',
#   'merchant',
#   'internet',
#   'mobil',
#   'network',
#   'provid',
#   'new',
#   'rapid',
#   'evolv',
#   'intens',
#   'competit',
#   'channel',
#   'sale',
#   'type',
#   'good',
#   'compet',
#   'two',
#   'side',
#   'must',
#   'attract',
#   'buyer',
#   'seller',
#   'use',
#   'platform',
#   'consum',
#   'purchas',
#   'sell',
#   'good',
#   'altern',
#   'merchant',
#   'channel',
#   'reach',
#   'consum',
#   'expect',
#   'competit',
#   'continu',
#   'intensifi',
#   'onlin',
#   'offlin',
#   'increas',
#   'compet',
#   'competitor',
#   'number',
#   'onlin',
#   'offlin',
#   'retail',
#   'signific',
#   'resourc',
#   'larg',
#   'communiti',
#   'well',
#   'establish',
#   'brand',
#   'moreov',
#   'barrier',
#   'entri',
#   'channel',
#   'low',
#   'easili',
#   'launch',
#   'onlin',
#   'site',
#   'mobil',
#   'platform',
#   'applic',
#   'nomin',
#   'use',
#   'commerci',
#   'avail',
#   'softwar',
#   'partner',
#   'number',
#   'success',
#   'ecommerc',
#   'respond',
#   'competit',
#   'environ',
#   'time',
#   'time',
#   'make',
#   'price',
#   'decis',
#   'acquisit',
#   'controversi',
#   'lead',
#   'dissatisfact',
#   'among',
#   'seller',
#   'reduc',
#   'activ',
#   'platform',
#   'harm',
#   'profit',
#   'face',
#   'increas',
#   'competit',
#   'pressur',
#   'onlin',
#   'offlin',
#   'particular',
#   'competit',
#   'norm',
#   'expect',
#   'level',
#   'ecommerc',
#   'mobil',
#   'commerc',
#   'signific',
#   'increas',
#   'due',
#   'among',
#   'factor',
#   'improv',
#   'experi',
#   'greater',
#   'eas',
#   'buy',
#   'good',
#   'lower',
#   'ship',
#   'faster',
#   'ship',
#   'time',
#   'favor',
#   'return',
#   'polici',
#   'certain',
#   'platform',
#   'alibaba',
#   'appl',
#   'googl',
#   'facebook',
#   'mani',
#   'larger',
#   'greater',
#   'capit',
#   'domin',
#   'secur',
#   'posit',
#   'industri',
#   'certain',
#   'signific',
#   'offer',
#   'good',
#   'consum',
#   'merchant',
#   'offer',
#   'unabl',
#   'offer',
#   'way',
#   'reflect',
#   'demand',
#   'ecommerc',
#   'mobil',
#   'commerc',
#   'marketplac',
#   'particular',
#   'higher',
#   'growth',
#   'sale',
#   'fix',
#   'price',
#   'item',
#   'higher',
#   'expect',
#   'level',
#   'depend',
#   'provid',
#   'seller',
#   'platform',
#   'compet',
#   'effect',
#   'adapt',
#   'larger',
#   'platform',
#   'suffer',
#   'competitor',
#   'revenu',
#   'sourc',
#   'abl',
#   'devot',
#   'resourc',
#   'promot',
#   'campaign',
#   'adopt',
#   'aggress',
#   'price',
#   'polici',
#   'devot',
#   'resourc',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'system',
#   'develop',
#   'competitor',
#   'offer',
#   'continu',
#   'offer',
#   'faster',
#   'free',
#   'ship',
#   'deliveri',
#   'sunday',
#   'day',
#   'deliveri',
#   'favor',
#   'return',
#   'polici',
#   'transact',
#   'relat',
#   'improv',
#   'experi',
#   'site',
#   'impract',
#   'ineffici',
#   'seller',
#   'match',
#   'competitor',
#   'abl',
#   'innov',
#   'faster',
#   'effici',
#   'new',
#   'technolog',
#   'increas',
#   'competit',
#   'pressur',
#   'enabl',
#   'competitor',
#   'offer',
#   'effici',
#   'lower',
#   'competitor',
#   'control',
#   'import',
#   'success',
#   'credit',
#   'card',
#   'interchang',
#   'internet',
#   'search',
#   'mobil',
#   'oper',
#   'system',
#   'competitor',
#   'manipul',
#   'price',
#   'avail',
#   'term',
#   'relat',
#   'manner',
#   'impact',
#   'competit',
#   'offer',
#   'exampl',
#   'googl',
#   'oper',
#   'shop',
#   'platform',
#   'time',
#   'time',
#   'make',
#   'search',
#   'algorithm',
#   'reduc',
#   'amount',
#   'search',
#   'traffic',
#   'direct',
#   'search',
#   'googl',
#   'unabl',
#   'use',
#   'adapt',
#   'oper',
#   'face',
#   'higher',
#   'face',
#   'integr',
#   'technolog',
#   'barrier',
#   'lose',
#   'custom',
#   'caus',
#   'suffer',
#   'consum',
#   'might',
#   'use',
#   'site',
#   'buy',
#   'good',
#   'wide',
#   'varieti',
#   'altern',
#   'tradit',
#   'depart',
#   'warehous',
#   'boutiqu',
#   'discount',
#   'general',
#   'merchandis',
#   'store',
#   'well',
#   'onlin',
#   'mobil',
#   'tradit',
#   'retail',
#   'onlin',
#   'retail',
#   'relat',
#   'mobil',
#   'offer',
#   'onlin',
#   'offlin',
#   'classifi',
#   'shop',
#   'channel',
#   'offlin',
#   'onlin',
#   'home',
#   'shop',
#   'network',
#   'unit',
#   'state',
#   'amazon',
#   'com',
#   'recent',
#   'open',
#   'experiment',
#   'brick',
#   'mortar',
#   'store',
#   'new',
#   'york',
#   'citi',
#   'continu',
#   'expand',
#   'new',
#   'geographi',
#   'line',
#   'googl',
#   'wal',
#   'mart',
#   'target',
#   'sear',
#   'maci',
#   'penney',
#   'costco',
#   'offic',
#   'depot',
#   'stapl',
#   'officemax',
#   'sam',
#   'club',
#   'rakuten',
#   'yahoo',
#   'shop',
#   'msn',
#   'qvc',
#   'home',
#   'shop',
#   'network',
#   'among',
#   'other',
#   'addit',
#   'consum',
#   'larg',
#   'number',
#   'onlin',
#   'offlin',
#   'channel',
#   'focus',
#   'one',
#   'categori',
#   'offer',
#   'site',
#   'consum',
#   'turn',
#   'mani',
#   'offer',
#   'varieti',
#   'provid',
#   'channel',
#   'buyer',
#   'find',
#   'buy',
#   'item',
#   'seller',
#   'size',
#   'social',
#   'medium',
#   'onlin',
#   'aggreg',
#   'classifi',
#   'platform',
#   'craigslist',
#   'oodl',
#   'com',
#   'number',
#   'intern',
#   'websit',
#   'oper',
#   'schibst',
#   'asa',
#   'nasper',
#   'limit',
#   'consum',
#   'turn',
#   'shop',
#   'comparison',
#   'site',
#   'googl',
#   'shop',
#   'certain',
#   'fix',
#   'price',
#   'list',
#   'tradit',
#   'auction',
#   'style',
#   'list',
#   'format',
#   'increas',
#   'challeng',
#   'format',
#   'classifi',
#   'classifi',
#   'platform',
#   'offer',
#   'classifi',
#   'list',
#   'unit',
#   'state',
#   'varieti',
#   'intern',
#   'mani',
#   'oper',
#   'classifi',
#   'platform',
#   'compet',
#   'custom',
#   'advertis',
#   'establish',
#   'onlin',
#   'offlin',
#   'classifi',
#   'platform',
#   'compet',
#   'websit',
#   'onlin',
#   'shop',
#   'comparison',
#   'websit',
#   'shop',
#   'com',
#   'compet',
#   'site',
#   'googl',
#   'shop',
#   'rakuten',
#   'nextag',
#   'com',
#   'pricegrabb',
#   'com',
#   'shopzilla',
#   'buscap',
#   'latin',
#   'america',
#   'nasper',
#   'yahoo',
#   'search',
#   'offer',
#   'shop',
#   'search',
#   'engin',
#   'allow',
#   'consum',
#   'search',
#   'internet',
#   'specifi',
#   'addit',
#   'seller',
#   'increas',
#   'util',
#   'multipl',
#   'sale',
#   'channel',
#   'acquisit',
#   'new',
#   'custom',
#   'pay',
#   'search',
#   'relat',
#   'advertis',
#   'horizont',
#   'search',
#   'engin',
#   'site',
#   'googl',
#   'yahoo',
#   'naver',
#   'baidu',
#   'use',
#   'search',
#   'engin',
#   'pay',
#   'search',
#   'advertis',
#   'help',
#   'find',
#   'site',
#   'potenti',
#   'divert',
#   'onlin',
#   'shop',
#   'destin',
#   'consum',
#   'choos',
#   'search',
#   'horizont',
#   'search',
#   'engin',
#   'shop',
#   'comparison',
#   'websit',
#   'site',
#   'send',
#   'shop',
#   'destin',
#   'consum',
#   'merchant',
#   'might',
#   'use',
#   'site',
#   'sell',
#   'good',
#   'mani',
#   'altern',
#   'general',
#   'ecommerc',
#   'site',
#   'amazon',
#   'alibaba',
#   'special',
#   'site',
#   'etsi',
#   'intern',
#   'site',
#   'compet',
#   'seller',
#   'general',
#   'special',
#   'ecommerc',
#   'site',
#   'seller',
#   'choos',
#   'sell',
#   'good',
#   'channel',
#   'classifi',
#   'platform',
#   'consum',
#   'merchant',
#   'creat',
#   'sell',
#   'site',
#   'choos',
#   'purchas',
#   'onlin',
#   'advertis',
#   'instead',
#   'use',
#   'countri',
#   'onlin',
#   'site',
#   'larger',
#   'custom',
#   'base',
#   'greater',
#   'brand',
#   'recognit',
#   'well',
#   'competitor',
#   'better',
#   'understand',
#   'local',
#   'cultur',
#   'commerc',
#   'increas',
#   'compet',
#   'local',
#   'competitor',
#   'develop',
#   'countri',
#   'uniqu',
#   'advantag',
#   'greater',
#   'abil',
#   'oper',
#   'local',
#   'regulatori',
#   'author',
#   'addit',
#   'certain',
#   'manufactur',
#   'limit',
#   'ceas',
#   'distribut',
#   'onlin',
#   'channel',
#   'site',
#   'manufactur',
#   'attempt',
#   'use',
#   'contractu',
#   'oblig',
#   'exist',
#   'futur',
#   'govern',
#   'regul',
#   'prohibit',
#   'limit',
#   'ecommerc',
#   'certain',
#   'categori',
#   'good',
#   'manufactur',
#   'attempt',
#   'enforc',
#   'minimum',
#   'resal',
#   'price',
#   'mainten',
#   'minimum',
#   'advertis',
#   'price',
#   'arrang',
#   'prevent',
#   'distributor',
#   'sell',
#   'platform',
#   'internet',
#   'general',
#   'price',
#   'would',
#   'make',
#   'attract',
#   'relat',
#   'altern',
#   'adopt',
#   'manufactur',
#   'polici',
#   'use',
#   'regul',
#   'case',
#   'discourag',
#   'restrict',
#   'sale',
#   'good',
#   'internet',
#   'forc',
#   'stop',
#   'sell',
#   'certain',
#   'platform',
#   'reduc',
#   'oper',
#   'margin',
#   'loss',
#   'share',
#   'diminish',
#   'valu',
#   'brand',
#   'princip',
#   'competit',
#   'factor',
#   'follow',
#   'abil',
#   'attract',
#   'retain',
#   'engag',
#   'buyer',
#   'seller',
#   'abil',
#   'attract',
#   'retain',
#   'engag',
#   'buyer',
#   'seller',
#   'volum',
#   'transact',
#   'price',
#   'select',
#   'good',
#   'volum',
#   'transact',
#   'price',
#   'select',
#   'good',
#   'trust',
#   'seller',
#   'transact',
#   'trust',
#   'seller',
#   'transact',
#   'communiti',
#   'cohes',
#   'interact',
#   'size',
#   'communiti',
#   'cohes',
#   'interact',
#   'size',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'eas',
#   'use',
#   'access',
#   'websit',
#   'mobil',
#   'platform',
#   'applic',
#   'eas',
#   'use',
#   'access',
#   'system',
#   'reliabl',
#   'secur',
#   'system',
#   'reliabl',
#   'secur',
#   'reliabl',
#   'deliveri',
#   'payment',
#   'custom',
#   'prefer',
#   'fast',
#   'deliveri',
#   'free',
#   'ship',
#   'return',
#   'reliabl',
#   'deliveri',
#   'payment',
#   'custom',
#   'prefer',
#   'fast',
#   'deliveri',
#   'free',
#   'ship',
#   'return',
#   'level',
#   'fee',
#   'level',
#   'fee',
#   'qualiti',
#   'search',
#   'tool',
#   'qualiti',
#   'search',
#   'tool',
#   'unabl',
#   'compet',
#   'success',
#   'current',
#   'futur',
#   'competitor',
#   'current',
#   'potenti',
#   'competitor',
#   'longer',
#   'oper',
#   'histori',
#   'larger',
#   'custom',
#   'base',
#   'greater',
#   'brand',
#   'recognit',
#   'internet',
#   'sector',
#   'global',
#   'region',
#   'econom',
#   'condit',
#   'harm',
#   'perform',
#   'depend',
#   'signific',
#   'global',
#   'region',
#   'econom',
#   'condit',
#   'advers',
#   'econom',
#   'condit',
#   'event',
#   'volatil',
#   'distress',
#   'equiti',
#   'debt',
#   'credit',
#   'past',
#   'negat',
#   'impact',
#   'region',
#   'global',
#   'like',
#   'continu',
#   'time',
#   'time',
#   'futur',
#   'uncertainti',
#   'relat',
#   'abil',
#   'greec',
#   'remain',
#   'european',
#   'monetari',
#   'union',
#   'advers',
#   'impact',
#   'economi',
#   'european',
#   'union',
#   'import',
#   'event',
#   'condit',
#   'negat',
#   'advers',
#   'impact',
#   'custom',
#   'caus',
#   'write',
#   'asset',
#   'invest',
#   'addit',
#   'turmoil',
#   'affect',
#   'bank',
#   'system',
#   'caus',
#   'addit',
#   ...],
#  ['care',
#   'review',
#   'follow',
#   'discuss',
#   'risk',
#   'affect',
#   'condit',
#   'well',
#   'consolid',
#   'statement',
#   'note',
#   'inform',
#   'appear',
#   'report',
#   'import',
#   'inform',
#   'regard',
#   'risk',
#   'affect',
#   'risk',
#   'factor',
#   'affect',
#   'condit',
#   'oper',
#   'subject',
#   'various',
#   'risk',
#   'uncertainti',
#   'advers',
#   'affect',
#   'condit',
#   'flow',
#   'well',
#   'trade',
#   'price',
# ...
#   'annual',
#   'oper',
#   'fourth',
#   'quarter',
#   'oper',
#   'fluctuat',
#   'signific',
#   'base',
#   'mani',
#   'factor',
#   'holiday',
#   'spend',
#   'pattern',
#   'weather',
#   'condit',
#   'sale',
#   'fluctuat',
#   'varieti',
#   'reason',
#   'advers',
#   'affect',
#   'sensit',
#   'custom',
#   'spend',
#   'pattern',
#   'turn',
#   'subject',
#   'prevail',
#   'econom',
#   'condit',
#   'sale',
#   'fluctuat',
#   'past',
#   'expect',
#   'continu',
#   'fluctuat',
#   'futur',
#   'varieti',
#   'factor',
#   'affect',
#   'sale',
#   'perform',
#   'action',
#   'competitor',
#   'open',
#   'new',
#   'store',
#   'exist',
#   'way',
#   'competitor',
#   'onlin',
#   'action',
#   'competitor',
#   'open',
#   'new',
#   'store',
#   'exist',
#   'way',
#   'competitor',
#   'onlin',
#   'season',
#   'fluctuat',
#   'due',
#   'weather',
#   'condit',
#   'season',
#   'fluctuat',
#   'due',
#   'weather',
#   'condit',
#   'merchandis',
#   'strategi',
#   'mix',
#   'merchandis',
#   'strategi',
#   'mix',
#   'popul',
#   'demograph',
#   'popul',
#   'demograph',
#   'time',
#   'promot',
#   'event',
#   'time',
#   'promot',
#   'event',
#   'accord',
#   'one',
#   'quarter',
#   'necessarili',
#   'indic',
#   'expect',
#   'quarter',
#   'compar',
#   'store',
#   'sale',
#   'particular',
#   'futur',
#   'period',
#   'increas',
#   'decreas',
#   'inform',
#   'see',
#   'manag',
#   'discuss',
#   'analysi',
#   'condit',
#   'item',
#   'report',
#   'form',
#   'reli',
#   'foreign',
#   'sourc',
#   'signific',
#   'amount',
#   'merchandis',
#   'negat',
#   'affect',
#   'risk',
#   'associ',
#   'intern',
#   'trade',
#   'depend',
#   'larg',
#   'number',
#   'produc',
#   'foreign',
#   'face',
#   'risk',
#   'associ',
#   'deliveri',
#   'merchandis',
#   'origin',
#   'outsid',
#   'unit',
#   'state',
#   'potenti',
#   'econom',
#   'polit',
#   'instabl',
#   'countri',
#   'supplier',
#   'locat',
#   'potenti',
#   'econom',
#   'polit',
#   'instabl',
#   'countri',
#   'supplier',
#   'locat',
#   'increas',
#   'ship',
#   'increas',
#   'ship',
#   'transport',
#   'delay',
#   'interrupt',
#   'transport',
#   'delay',
#   'interrupt',
#   'advers',
#   'fluctuat',
#   'currenc',
#   'exchang',
#   'rate',
#   'advers',
#   'fluctuat',
#   'currenc',
#   'exchang',
#   'rate',
#   'foreign',
#   'affect',
#   'import',
#   'taxat',
#   'good',
#   'duti',
#   'tariff',
#   'quota',
#   'enforc',
#   'foreign',
#   'affect',
#   'import',
#   'taxat',
#   'good',
#   'duti',
#   'tariff',
#   'quota',
#   'enforc',
#   'reli',
#   'extens',
#   'comput',
#   'system',
#   'process',
#   'transact',
#   'summar',
#   'manag',
#   'disrupt',
#   'system',
#   'harm',
#   'abil',
#   'run',
#   'give',
#   'number',
#   'individu',
#   'transact',
#   'year',
#   'critic',
#   'maintain',
#   'uninterrupt',
#   'comput',
#   'communic',
#   'hardwar',
#   'softwar',
#   'system',
#   'system',
#   'subject',
#   'damag',
#   'interrupt',
#   'power',
#   'outag',
#   'comput',
#   'telecommun',
#   'failur',
#   'comput',
#   'virus',
#   'catastroph',
#   'event',
#   'fire',
#   'tornado',
#   'hurrican',
#   'usag',
#   'error',
#   'employe',
#   'system',
#   'breach',
#   'damag',
#   'ceas',
#   'function',
#   'proper',
#   'make',
#   'signific',
#   'invest',
#   'fix',
#   'replac',
#   'suffer',
#   'interrupt',
#   'interim',
#   'face',
#   'cost',
#   'litig',
#   'materi',
#   'interrupt',
#   'comput',
#   'materi',
#   'advers',
#   'effect',
#   'addit',
#   'pursu',
#   'complex',
#   'initi',
#   'transform',
#   'inform',
#   'technolog',
#   'process',
#   'system',
#   'risk',
#   'disrupt',
#   'increas',
#   'period',
#   'complex',
#   'signific',
#   'system',
#   'undertak',
#   'maintain',
#   'secur',
#   'member',
#   'custom',
#   'associ',
#   'inform',
#   'damag',
#   'reput',
#   'incur',
#   'substanti',
#   'addit',
#   'becom',
#   'subject',
#   'litig',
#   'signific',
#   'secur',
#   'compromis',
#   'breach',
#   'member',
#   'custom',
#   'associ',
#   'data',
#   'either',
#   'hold',
#   'maintain',
#   'third',
#   'parti',
#   'provid',
#   'signific',
#   'damag',
#   'reput',
#   'brand',
#   'addit',
#   'lose',
#   'sale',
#   'fine',
#   'lawsuit',
#   'regulatori',
#   'environ',
#   'relat',
#   'inform',
#   'secur',
#   'privaci',
#   'increas',
#   'rigor',
#   'new',
#   'constant',
#   'requir',
#   'applic',
#   'complianc',
#   'requir',
#   'addit',
#   'guarante',
#   'procedur',
#   'implement',
#   'protect',
#   'unauthor',
#   'access',
#   'secur',
#   'data',
#   'adequ',
#   'safeguard',
#   'data',
#   'secur',
#   'breach',
#   'data',
#   ...],
#  ['subject',
#   'various',
#   'risk',
#   'uncertainti',
#   'describ',
#   'advers',
#   'affect',
#   'condit',
#   'unabl',
#   'compet',
#   'effect',
#   'high',
#   'competit',
#   'retail',
#   'industri',
#   'materi',
#   'advers',
#   'affect',
#   'retail',
#   'industri',
#   'high',
#   'competit',
#   'barrier',
#   'entri',
#   'compet',
#   'wide',
#   'varieti',
#   'retail',
#   'depart',
#   'store',
#   'discount',
#   'home',
#   'improv',
#   'store',
#   'applianc',
#   'consum',
#   'electron',
#   'retail',
#   'auto',
#   'provid',
#   'specialti',
#   'retail',
#   'wholesal',
#   'club',
#   'onlin',
#   'catalog',
#   'retail',
#   'mani',
#   'competitor',
#   'oper',
#   'nation',
#   'region',
#   'local',
#   'level',
#   'competitor',
#   'activ',
#   'engag',
#   'new',
#   'store',
#   'expans',
#   'onlin',
#   'catalog',
#   'handl',
#   'similar',
#   'line',
#   'merchandis',
#   'collect',
#   'sale',
#   'purchas',
#   'make',
#   'custom',
#   'compet',
#   'competit',
#   'intensifi',
#   'competitor',
#   'enter',
#   'combin',
#   'allianc',
#   'experi',
#   'signific',
#   'competit',
#   'promot',
#   'activ',
#   'competitor',
#   'competitor',
#   'abl',
#   'devot',
#   'greater',
#   'resourc',
#   'sourc',
#   'promot',
#   'sell',
#   'competit',
#   'marketplac',
#   'success',
#   'base',
#   'factor',
#   'price',
#   'advertis',
#   'assort',
#   'qualiti',
#   'reput',
#   'conveni',
#   'success',
#   'depend',
#   'abil',
#   'differenti',
#   'competitor',
#   'respect',
#   'shop',
#   'conveni',
#   'qualiti',
#   'assort',
#   'avail',
#   'merchandis',
#   'function',
#   'digit',
#   'channel',
#   'superior',
#   'custom',
#   'experi',
#   'must',
#   'success',
#   'respond',
#   'member',
#   'custom',
#   'tast',
#   'expect',
#   'perform',
#   'competitor',
#   'well',
#   'price',
#   'polici',
#   'activ',
#   'new',
#   'store',
#   'open',
#   'strategi',
#   'materi',
#   'advers',
#   'effect',
#   'condit',
#   'fail',
#   'offer',
#   'merchandis',
#   'member',
#   'custom',
#   'want',
#   'sale',
#   'limit',
#   'would',
#   'reduc',
#   'revenu',
#   'profit',
#   'order',
#   'success',
#   'must',
#   'identifi',
#   'obtain',
#   'suppli',
#   'offer',
#   'member',
#   'custom',
#   'attract',
#   'innov',
#   'high',
#   'qualiti',
#   'merchandis',
#   'must',
#   'satisfi',
#   'desir',
#   'member',
#   'custom',
#   'whose',
#   'prefer',
#   'futur',
#   'sale',
#   'oper',
#   'depend',
#   'part',
#   'abil',
#   'predict',
#   'consum',
#   'demand',
#   'sell',
#   'avail',
#   'merchandis',
#   'trend',
#   'member',
#   'custom',
#   'purchas',
#   'habit',
#   'tast',
#   'prefer',
#   'misjudg',
#   'predict',
#   'relationship',
#   'member',
#   'custom',
#   'negat',
#   'impact',
#   'face',
#   'excess',
#   'inventori',
#   'impact',
#   'sale',
#   'sell',
#   'merchandis',
#   'obtain',
#   'lower',
#   'price',
#   'miss',
#   'opportun',
#   'choos',
#   'offer',
#   'addit',
#   'merchandis',
#   'misjudg',
#   'advers',
#   'impact',
#   'percept',
#   'reput',
#   'declin',
#   'member',
#   'custom',
#   'loyalti',
#   'vendor',
#   'relationship',
#   'factor',
#   'negat',
#   'effect',
#   'condit',
#   'integr',
#   'retail',
#   'strategi',
#   'transform',
#   'member',
#   'centric',
#   'retail',
#   'success',
#   'advers',
#   'affect',
#   'seek',
#   'transform',
#   'member',
#   'centric',
#   'retail',
#   'integr',
#   'retail',
#   'strategi',
#   'base',
#   'number',
#   'initi',
#   'shop',
#   'way',
#   'program',
#   'depend',
#   'among',
#   'thing',
#   'abil',
#   'respond',
#   'quick',
#   'ongo',
#   'technolog',
#   'develop',
#   'implement',
#   'new',
#   'way',
#   'understand',
#   'reli',
#   'data',
#   'interact',
#   'member',
#   'custom',
#   'abil',
#   'provid',
#   'attract',
#   'conveni',
#   'consist',
#   'onlin',
#   'mobil',
#   'experi',
#   'member',
#   'must',
#   'anticip',
#   'meet',
#   'member',
#   'custom',
#   'evolv',
#   'expect',
#   'counteract',
#   'develop',
#   'competitor',
#   'strive',
#   'deliv',
#   'seamless',
#   'experi',
#   'across',
#   'sale',
#   'channel',
#   'need',
#   'adjust',
#   'strateg',
#   'initi',
#   'depend',
#   'member',
#   'custom',
#   'reaction',
#   'level',
#   'engag',
#   'initi',
#   'failur',
#   'execut',
#   'initi',
#   'provid',
#   'member',
#   'posit',
#   'experi',
#   'loss',
#   'activ',
#   'member',
#   'failur',
#   'attract',
#   'new',
#   'member',
#   'lower',
#   'anticip',
#   'sale',
#   'assur',
#   'initi',
#   'strategi',
#   'improv',
#   'oper',
#   'success',
#   'manag',
#   'inventori',
#   'level',
#   'oper',
#   'advers',
#   'affect',
#   'must',
#   'maintain',
#   'suffici',
#   'inventori',
#   'level',
#   'oper',
#   'success',
#   'howev',
#   'must',
#   'guard',
#   'accumul',
#   'excess',
#   'inventori',
#   'seek',
#   'minim',
#   'stock',
#   'level',
#   'across',
#   'categori',
#   'maintain',
#   'stock',
#   'level',
#   'obtain',
#   'signific',
#   'portion',
#   'inventori',
#   'vendor',
#   'locat',
#   'outsid',
#   'unit',
#   'state',
#   'vendor',
#   'lengthi',
#   'advanc',
#   'notic',
#   'requir',
#   'order',
#   'abl',
#   'suppli',
#   'quantiti',
#   'request',
#   'usual',
#   'order',
#   'merchandis',
#   'enter',
#   'purchas',
#   'order',
#   'contract',
#   'purchas',
#   'manufactur',
#   'merchandis',
#   'well',
#   'advanc',
#   'time',
#   'offer',
#   'sale',
#   'experi',
#   'difficulti',
#   'respond',
#   'quick',
#   'retail',
#   'environ',
#   'make',
#   'vulner',
#   'price',
#   'demand',
#   'accur',
#   'anticip',
#   'futur',
#   'demand',
#   'particular',
#   'time',
#   'take',
#   'obtain',
#   'new',
#   'inventori',
#   'inventori',
#   'level',
#   'appropri',
#   'negat',
#   'impact',
#   'continu',
#   'affect',
#   'worldwid',
#   'econom',
#   'condit',
#   'econom',
#   'downturn',
#   'renew',
#   'declin',
#   'consum',
#   'spend',
#   'level',
#   'condit',
#   'inflat',
#   'price',
#   'energi',
#   'lead',
#   'reduc',
#   'revenu',
#   'gross',
#   'margin',
#   'negat',
#   'impact',
#   'liquid',
#   'mani',
#   'econom',
#   'factor',
#   'outsid',
#   'control',
#   'consum',
#   'commerci',
#   'credit',
#   'avail',
#   'consum',
#   'confid',
#   'spend',
#   'level',
#   'well',
#   'impact',
#   'payrol',
#   'medic',
#   'increas',
#   'consum',
#   'recess',
#   'inflat',
#   'deflat',
#   'employ',
#   'level',
#   'hous',
#   'sale',
#   'remodel',
#   'interest',
#   'rate',
#   'rate',
#   'rate',
#   'econom',
#   'growth',
#   'fiscal',
#   'monetari',
#   'govern',
#   'polici',
#   'consum',
#   'debt',
#   'level',
#   'consum',
#   'debt',
#   'payment',
#   'behavior',
#   'fuel',
#   'challeng',
#   'current',
#   'affect',
#   'global',
#   'economi',
#   'full',
#   'impact',
#   'condit',
#   'cannot',
#   'predict',
#   'certainti',
#   'econom',
#   'condit',
#   'advers',
#   'affect',
#   'dispos',
#   'incom',
#   'level',
#   'credit',
#   'avail',
#   'member',
#   'custom',
#   'lead',
#   'reduc',
#   'demand',
#   'merchandis',
#   'although',
#   'fuel',
#   'energi',
#   'decreas',
#   'recent',
#   'month',
#   'futur',
#   'increas',
#   'signific',
#   'impact',
#   'signific',
#   'quantiti',
#   'fuel',
#   'vehicl',
#   'use',
#   'technician',
#   'home',
#   'expos',
#   'risk',
#   'associ',
#   'variat',
#   'price',
#   'petroleum',
#   'experi',
#   'disrupt',
#   'energi',
#   'suppli',
#   'suppli',
#   'gasolin',
#   'factor',
#   'beyond',
#   'control',
#   'advers',
#   'effect',
#   'certain',
#   'vendor',
#   'experi',
#   'increas',
#   'various',
#   'raw',
#   'materi',
#   'cotton',
#   'oil',
#   'relat',
#   'materi',
#   'steel',
#   'rubber',
#   'increas',
#   'price',
#   'pay',
#   'merchandis',
#   'particular',
#   'apparel',
#   'applianc',
#   'tire',
#   'domest',
#   'intern',
#   'polit',
#   'event',
#   'affect',
#   'consum',
#   'confid',
#   'threat',
#   'outbreak',
#   'escal',
#   'terror',
#   'civil',
#   'unrest',
#   'militari',
#   'conflict',
#   'hostil',
#   'lead',
#   'decreas',
#   'consum',
#   'spend',
#   'event',
#   'condit',
#   'inhibit',
#   'sale',
#   'caus',
#   'increas',
#   'inventori',
#   'markdown',
#   'promot',
#   'expens',
#   'therebi',
#   'reduc',
#   'gross',
#   'margin',
#   'lack',
#   'willing',
#   'vendor',
#   'provid',
#   'accept',
#   'payment',
#   'term',
#   'negat',
#   'impact',
#   'liquid',
#   'reduc',
#   'avail',
#   'seek',
#   'procur',
#   'depend',
#   'vendor',
#   'provid',
#   'financ',
#   'purchas',
#   'inventori',
#   'vendor',
#   'seek',
#   'limit',
#   'avail',
#   'vendor',
#   'credit',
#   'modifi',
#   'term',
#   'sell',
#   'negat',
#   'impact',
#   'liquid',
#   'addit',
#   'inabl',
#   'vendor',
#   'access',
#   'liquid',
#   'insolv',
#   'vendor',
#   'lead',
#   'failur',
#   'deliv',
#   'inventori',
#   'certain',
#   'vendor',
#   'financ',
#   'reduc',
#   'risk',
#   'associ',
#   'collect',
#   'account',
#   'receiv',
#   'sell',
#   'factor',
#   'receiv',
#   'purchas',
#   'credit',
#   'insur',
#   'form',
#   'protect',
#   'loss',
#   'associ',
#   'credit',
#   'risk',
#   'abil',
#   'vendor',
#   'subject',
#   'perceiv',
#   'credit',
#   'qualiti',
#   'vendor',
#   'limit',
#   'abil',
#   'factor',
#   'receiv',
#   'obtain',
#   'credit',
#   'protect',
#   'futur',
#   'perceiv',
#   'posit',
#   'creditworthi',
#   'reduc',
#   'avail',
#   'seek',
#   'procur',
#   'increas',
#   'ongo',
#   'discuss',
#   'concern',
#   'liquid',
#   'posit',
#   'vendor',
#   'communiti',
#   'third',
#   'parti',
#   'offer',
#   'various',
#   'credit',
#   'protect',
#   'vendor',
#   'topic',
#   'discuss',
#   'area',
#   'price',
#   'payment',
#   'term',
#   'ongo',
#   'arrang',
#   'date',
#   'report',
#   'experi',
#   'signific',
#   'disrupt',
#   'access',
#   'merchandis',
#   'howev',
#   'assur',
#   'one',
#   'vendor',
#   'slow',
#   'ceas',
#   'merchandis',
#   'shipment',
#   'condit',
#   'sale',
#   'shipment',
#   'merchandis',
#   'new',
#   'payment',
#   'term',
#   'assur',
#   'circumst',
#   'negat',
#   'effect',
#   'condit',
#   'certain',
#   'factor',
#   'condit',
#   'credit',
#   'rat',
#   'limit',
#   'access',
#   'capit',
#   'financ',
#   'sourc',
#   'materi',
#   'increas',
#   'borrow',
#   'addit',
#   'credit',
#   'term',
#   'vendor',
#   'liquid',
#   'need',
#   'fund',
#   'oper',
#   'flow',
#   'extent',
#   'necessari',
#   'borrow',
#   'credit',
#   'agreement',
#   'commerci',
#   'paper',
#   'program',
#   'asset',
#   'sale',
#   'access',
#   'capit',
#   'avail',
#   'financ',
#   'depend',
#   'numer',
#   'factor',
#   'econom',
#   'condit',
#   'oper',
#   'perform',
#   'credit',
#   'rat',
#   'lender',
#   'assess',
#   'prospect',
#   'prospect',
#   'retail',
#   'industri',
#   'general',
#   'factor',
#   'affect',
#   'financ',
#   'liquid',
#   'abil',
#   'access',
#   'financ',
#   'sourc',
#   'commerci',
#   'paper',
#   'program',
#   'possibl',
#   'second',
#   'lien',
#   'indebted',
#   'permit',
#   'domest',
#   'revolv',
#   'credit',
#   'facil',
#   'respect',
#   'lender',
#   'commit',
#   'rat',
#   'agenc',
#   'revis',
#   'rat',
#   'follow',
#   'time',
#   'time',
#   'sever',
#   'rat',
#   'agenc',
#   'downgrad',
#   'credit',
#   'rat',
#   'certain',
#   'outstand',
#   'debt',
#   'instrument',
#   'six',
#   'month',
#   'preced',
#   'date',
#   'report',
#   'rat',
#   'revis',
#   'withdraw',
#   'entireti',
#   'time',
#   'domest',
#   'credit',
#   'facil',
#   'current',
#   'provid',
#   'billion',
#   'lender',
#   'commit',
#   'billion',
#   'revolv',
#   'commit',
#   'abil',
#   'borrow',
#   'fund',
#   'facil',
#   'limit',
#   'borrow',
#   'base',
#   'determin',
#   'valu',
#   'time',
#   'time',
#   'elig',
#   'inventori',
#   'account',
#   'receiv',
#   'certain',
#   'asset',
#   'asset',
#   'sale',
#   'mean',
#   'valu',
#   'elig',
#   'asset',
#   'suffici',
#   'support',
#   'borrow',
#   'full',
#   'amount',
#   'commit',
#   'facil',
#   'full',
#   'access',
#   'facil',
#   'rather',
#   'access',
#   'lesser',
#   'amount',
#   'determin',
#   'borrow',
#   'base',
#   'declin',
#   'valu',
#   'elig',
#   'asset',
#   'inabl',
#   'borrow',
#   'full',
#   'amount',
#   'second',
#   'lien',
#   'indebted',
#   'permit',
#   'domest',
#   'credit',
#   'facil',
#   'second',
#   'lien',
#   'borrow',
#   'limit',
#   'borrow',
#   'base',
#   'requir',
#   'indentur',
#   'govern',
#   'senior',
#   'secur',
#   'note',
#   'due',
#   'domest',
#   'revolv',
#   'credit',
#   'facil',
#   'impos',
#   'various',
#   'requir',
#   'take',
#   'effect',
#   'avail',
#   'fall',
#   'design',
#   'threshold',
#   'dominion',
#   'requir',
#   'domest',
#   'credit',
#   'facil',
#   'effect',
#   'limit',
#   'full',
#   'access',
#   'facil',
#   'fix',
#   'charg',
#   'ratio',
#   'last',
#   'day',
#   'quarter',
#   'januari',
#   'fix',
#   'charg',
#   'ratio',
#   'avail',
#   'domest',
#   'revolv',
#   'credit',
#   'facil',
#   'fall',
#   'would',
#   'test',
#   'fix',
#   'charg',
#   'coverag',
#   'ratio',
#   'would',
#   'compli',
#   'facil',
#   'lender',
#   'facil',
#   'demand',
#   'immedi',
#   'payment',
#   'full',
#   'amount',
#   'outstand',
#   'termin',
#   'oblig',
#   'facil',
#   'addit',
#   'domest',
#   'credit',
#   'facil',
#   'provid',
#   'event',
#   'make',
#   'certain',
#   'prepay',
#   'indebted',
#   'period',
#   'one',
#   'year',
#   'thereaft',
#   'must',
#   'maintain',
#   'avail',
#   'facil',
#   'least',
#   ...]]

# %% [markdown]
# <a id="bag_of_words"></a>

# %% [markdown]
# ## 1. Bag-of-Words

# %% [markdown]
# Implement a function that converts a list of tokenized words into bag-of-words, i.e. a dictionary that outputs the frequency count of a word
#
# ** python already provide the `collections.Counter` class to perform this, but I encourage you to implement your own function as an exercise
#
# <a href="#table_of_content">back to top</a>

# %%
from collections import defaultdict

def bag_of_words(words):
    bag = defaultdict(int)
    for w in words:
        bag[w] += 1
    return bag

# %% [markdown]
# <a id="sentiment"></a>

# %% [markdown]
# ## 2. Sentiments
# Count the fraction of words that appear in a wordlist, returning a sentiment score between 0 and 1:
#
# $$
# \textrm{score} = \frac{\textrm{Number of words in document matching wordlist}}{\textrm{Number of words in document}}
# $$
#
# Implement the score in a function `get_sentiment(words, wordlist)`, where words is a list of words. Feel free to use the previous `bag_of_words` function.
# (*for extra challenge, try to code the function in one-line*)
#
# Here, I've included a positive and negative wordlist that I constructed by hand. Due to copyright issues, we are not able to provide other commonly used wordlists. I encourage you to try out different wordlists on your own.
#
# <a href="#table_of_content">back to top</a>

# %%
# load wordlist first
import pickle

with open('positive_words.pickle', 'rb') as f:
    positive_words = pickle.load(f)
    # also need to stem and lemmatize the text
    positive_words = set(clean_text(" ".join(positive_words)))
    
with open('negative_words.pickle', 'rb') as f:
    negative_words = pickle.load(f)
    negative_words = set(clean_text(" ".join(negative_words)))
    
# check out the list
repugn', 'cloudi', 'evil', 'dead', 'reject', 'breach', 'obsolet', 'litig', 'wreck', 'argument', 'conced', 'dysfunct', 'scourg', 'usurp', 'unabl', 'content', 'illeg', 'shadi', 'disgust', 'unneed', 'scandal', 'blackmail', 'ineffect', 'repuls', 'vilifi', 'boycott', 'harsh', 'closur', 'unnecessari', 'underperform', 'empti', 'close', 'plea', 'horror', 'unsettl', 'vulgar', 'subpoena', 'break', 'crisi', 'desol', 'lower', 'defiant', 'strike', 'distress', 'calam', 'desist', 'lack', 'fruitless', 'neglect', 'taint', 'hurt', 'conflict', 'falsifi', 'nasti', 'worsen', 'pessimist', 'bust', 'imperil', 'turbul', 'exhaust', 'insolv', 'abhor', 'complic', 'impeach', 'erod', 'violat', 'bankrupt', 'lie', 'thiev', 'unattract', 'harsher', 'peril', 'misus', 'terribl', 'object', 'nastili', 'afflict', 'ban', 'doubt', 'degrad', 'impoverish', 'weaken', 'postpon', 'impedi', 'retreat', 'accident', 'hinder', 'insan', 'panic', 'hard', 'unfortun', 'fals', 'horribl', 'deprav', 'plung', 'appal', 'trivial', 'atroci', 'terror', 'suspens', 'woe', 'unproduct', 'uninspir', 'weak', 'violent', 'guilt', 'wors', 'investig', 'gloom', 'horrid', 'devast', 'blame', 'disqualif', 'debt', 'pollut', 'scorn', 'disast', 'demot', 'trial', 'unattain', 'inept', 'disfavor', 'imposs', 'perjuri', 'dampen', 'gloomi', 'embezzl', 'delay', 'incap', 'anomali', 'notori', 'guilti', 'accid', 'critic', 'lazi', 'contempt', 'unhappi', 'invalid', 'untal', 'shame', 'dark', 'low', 'wick', 'fraudul', 'malic', 'hardship', 'unwelcom', 'shutdown', 'instabl', 'headach', 'deplor', 'inconveni', 'contradict', 'obsolesc', 'refus', 'kill', 'fail', 'horrend', 'incident', 'crash', 'miseri', 'incompat', 'antiqu', 'confus', 'malign', 'unstabl', 'fatal', 'unfruit', 'leak', 'death', 'abhorr', 'fear', 'intimid', 'rotten', 'sacrifici', 'dissolv', 'penalti', 'injur', 'pessim', 'danger', 'misappl', 'disapprov', 'balk', 'agoni', 'aw', 'powerless', 'repudi', 'crime', 'harm', 'harrow', 'frustrat', 'untrustworthi', 'collus', 'storm', 'destroy', 'difficulti', 'abandon', 'apathi', 'devalu', 'breakabl', 'mockeri', 'stress', 'misfortun', 'curs', 'damag', 'unlaw', 'ugli', 'catastroph', 'doom', 'defianc', 'ceas', 'exacerb', 'hardest', 'dirtili', 'faulti', 'upset', 'downgrad', 'disclaim', 'vice', 'escal', 'lag', 'pressur', 'abnorm', 'malfunct', 'arrest', 'hostil', 'troubl', 'aggrav', 'avoid', 'doomsday', 'overpay', 'nefari', 'strain', 'shrink', 'abomin', 'incid', 'discredit', 'steal', 'inabl', 'bottleneck', 'fire', 'hate', 'weari', 'recal', 'attrit', 'delus', 'eros', 'drain', 'loot', 'uneth', 'deris', 'revolt', 'failur', 'inviabl', 'bankruptci', 'ridicul', 'erron', 'ineffici', 'collud', 'desper', 'unpopular', 'imped', 'disadvantag', 'troublesom', 'wrong', 'hatr', 'dismal', 'crack', 'obnoxi', 'counterfeit', 'temper', 'default', 'sacrific', 'oppress', 'vile', 'disinterest', 'dirti', 'forfeit', 'threat', 'nuisanc', 'sue', 'depress', 'flaw', 'deter', 'accus', 'sorrow', 'nullifi', 'odious', 'complaint', 'fiasco', 'difficult', 'excess', 'underwhelm', 'slow', 'fright', 'uncontrol', 'suspend', 'disqualifi', 'inferior', 'insol', 'apathet', 'hazard', 'blow', 'termin', 'urgent', 'decept', 'discourag', 'suspici', 'forgeri', 'objection', 'exploit', 'unscrupul', 'foul', 'rot', 'unnecessarili', 'deterior', 'renounc', 'blacklist', 'bribe', 'hamper', 'burden', 'disregard', 'fault', 'unworthi', 'murder', 'lawsuit', 'obstruct', 'disabl', 'unfair', 'illiquid', 'condemn', 'sever'}

# %%
def get_sentiment(txt, wordlist):
    matching_words = [ w for w in txt if w in wordlist ]
    return len(matching_words)/len(txt)

# %%
# test your function
positive_sentiments = np.array([ get_sentiment(c, positive_words) for c in corpus ])
print(positive_sentiments)

negative_sentiments = np.array([ get_sentiment(c, negative_words) for c in corpus ])
print(negative_sentiments)
# Out:
# [ 0.034  0.033  0.034  0.031  0.032  0.039  0.039  0.037  0.033  0.04 ]
# [ 0.051  0.05   0.054  0.061  0.061  0.062  0.061  0.06   0.059  0.059]

# %% [markdown]
# **before continuing part 2, go through the lesson material first!**

# %% [markdown]
# <a id="compute_idf"></a>

# %% [markdown]
# # Part 2 Document Vector Exercises
#
# ## 3. Computer idf
# Given a corpus, or a list of bag-of-words, we want to compute for each word $w$, the inverse-document-frequency, or ${\rm idf}(w)$. This can be done in a few steps:
#
# 1. Gather a set of all the words in all the bag-of-words (python set comes in handy, and the union operator `|` is useful here)
#
#
# 2. Loop over each word $w$, and compute ${\rm df}_w$, the number of documents where this word appears at least once. A dictionary is useful for keeping track of ${\rm df}_w$
#
#
# 3. After computing ${\rm df}_w$, we can compute ${\rm idf}(w)$. There are usually two possibilities, the simplest one is
# $${\rm idf}(w)=\frac{N}{{\rm df}_w}$$
# Where $N$ is the total number of documents in the corpus and $df_w$ the number of documents that contain the word $w$. Frequently, a logarithm term is added as well
# $${\rm idf}(w)=\log\frac{N}{{\rm df}_w}$$
# One issue with using the logarithm is that when ${\rm df}_w = N$, ${\rm idf}(w)=0$, indicating that words common to all documents would be ignored. If we don't want this behavior, we can define ${\rm idf}(w)=\log\left(1+N/{\rm df}_w\right)$ or ${\rm idf}(w)=1+\log\left(N/{\rm df}_w\right)$ instead. For us, we'll not use the extra +1 for ${\rm idf}$.
#
# In the following, define a function called `get_idf(corpus, include_log=True)` that computes ${\rm idf}(w)$ for all the words in a corpus, where `corpus` for us is a processed list of bag-of-words (stemmed and lemmatized). The optional parameter `include_log` includes the logarithm in the computation.
#
# <a href="#table_of_content">back to top</a>

# %%
# compute idf
import numpy as np
def get_idf(corpus, include_log=True):
    N = len(corpus)
    freq = defaultdict(int)
    words = set()
    for c in corpus:
        words |= set(c)        
    for w in words:
        freq[w] = sum([ w in c for c in corpus])

    if include_log:
        return { w: np.log(N/freq[w]) for w in freq }
    else:
        return { w: N/freq[w] for w in freq }

# %% [markdown]
# You should expect to see many idf values = 0! This is by design, because we have ${\rm idf}(w)=\log N_d/{\rm df}_w$ and $N_d/{\rm df}_w=1$ for the most common words!

# %%
# test your code
idf=get_idf(corpus)
print_sorted(idf, ascending=True)
# Out:
# deliveri: 0.000
# lengthi: 0.000
# declin: 0.000
# januari: 0.000
# indirect: 0.000
# indic: 0.000
# rat: 0.000
# good: 0.000
# secur: 0.000
# choos: 0.000
# ultim: 0.000
# consum: 0.000
# asset: 0.000
# valu: 0.000
# perform: 0.000
# incom: 0.000
# state: 0.000
# whether: 0.000
# share: 0.000
# damag: 0.000
# parti: 0.000
# shop: 0.000
# aggress: 0.000
# rise: 0.000
# control: 0.000
# opportun: 0.000
# regul: 0.000
# satisfi: 0.000
# deliv: 0.000
# depend: 0.000
# time: 0.000
# agreement: 0.000
# sourc: 0.000
# discourag: 0.000
# liquid: 0.000
# involv: 0.000
# high: 0.000
# relat: 0.000
# current: 0.000
# affect: 0.000
# common: 0.000
# custom: 0.000
# appropri: 0.000
# properti: 0.000
# industri: 0.000
# suffici: 0.000
# make: 0.000
# econom: 0.000
# whose: 0.000
# credit: 0.000
# locat: 0.000
# key: 0.000
# fluctuat: 0.000
# natur: 0.000
# statement: 0.000
# annual: 0.000
# procedur: 0.000
# confid: 0.000
# expans: 0.000
# continu: 0.000
# general: 0.000
# accord: 0.000
# experi: 0.000
# oper: 0.000
# barrier: 0.000
# amount: 0.000
# avail: 0.000
# financ: 0.000
# disput: 0.000
# disrupt: 0.000
# materi: 0.000
# threat: 0.000
# lender: 0.000
# form: 0.000
# vulner: 0.000
# affili: 0.000
# outag: 0.000
# abil: 0.000
# employ: 0.000
# facil: 0.000
# unfavor: 0.000
# identifi: 0.000
# advers: 0.000
# hire: 0.000
# intern: 0.000
# prospect: 0.000
# item: 0.000
# upon: 0.000
# purchas: 0.000
# addit: 0.000
# human: 0.000
# initi: 0.000
# new: 0.000
# part: 0.000
# ship: 0.000
# unit: 0.000
# fund: 0.000
# interact: 0.357
# hold: 0.357
# pattern: 0.357
# hostil: 0.357
# intellectu: 0.357
# valuat: 0.357
# feder: 0.357
# fine: 0.357
# collect: 0.357
# trademark: 0.357
# lack: 0.357
# privaci: 0.357
# other: 0.357
# perceiv: 0.357
# compar: 0.357
# understand: 0.357
# unauthor: 0.357
# beyond: 0.357
# right: 0.357
# indebted: 0.357
# catastroph: 0.357
# develop: 0.357
# holiday: 0.357
# analysi: 0.357
# dealer: 0.357
# privat: 0.357
# member: 0.357
# revolv: 0.357
# lose: 0.357
# follow: 0.357
# sharehold: 0.357
# transit: 0.357
# posit: 0.357
# replac: 0.357
# compromis: 0.357
# platform: 0.357
# withdraw: 0.357
# elect: 0.357
# weather: 0.357
# internet: 0.357
# issu: 0.357
# trend: 0.357
# guarante: 0.357
# integr: 0.357
# notic: 0.357
# injuri: 0.357
# status: 0.357
# secret: 0.357
# dress: 0.357
# step: 0.357
# fourth: 0.357
# transport: 0.357
# oversea: 0.357
# tariff: 0.357
# agenc: 0.357
# copyright: 0.357
# moreov: 0.357
# supplier: 0.357
# total: 0.357
# patent: 0.357
# implement: 0.357
# complianc: 0.357
# accept: 0.357
# becom: 0.357
# percentag: 0.511
# fraud: 0.511
# growth: 0.511
# favor: 0.511
# ownership: 0.511
# safeti: 0.511
# reduct: 0.511
# occurr: 0.511
# attempt: 0.511
# downturn: 0.511
# rais: 0.511
# complet: 0.511
# greater: 0.511
# among: 0.511
# type: 0.511
# altern: 0.511
# contain: 0.511
# array: 0.511
# provis: 0.511
# two: 0.511
# concern: 0.511
# princip: 0.511
# particip: 0.511
# money: 0.511
# entitl: 0.511
# settl: 0.511
# evolv: 0.511
# target: 0.511
# difficult: 0.511
# intent: 0.511
# acceler: 0.511
# alter: 0.511
# announc: 0.511
# allow: 0.511
# matter: 0.511
# conduct: 0.511
# consumm: 0.511
# break: 0.511
# whole: 0.511
# prevent: 0.511
# prohibit: 0.511
# theft: 0.511
# team: 0.511
# differenti: 0.511
# sanction: 0.511
# disposit: 0.511
# environment: 0.511
# trebl: 0.511
# specif: 0.511
# describ: 0.511
# specifi: 0.511
# histor: 0.511
# entiti: 0.511
# respons: 0.511
# rule: 0.511
# attack: 0.511
# contempl: 0.511
# calcul: 0.511
# trust: 0.511
# enhanc: 0.511
# facilit: 0.511
# higher: 0.511
# primari: 0.511
# advertis: 0.511
# sear: 0.511
# close: 0.511
# smaller: 0.511
# public: 0.511
# effici: 0.511
# denial: 0.511
# consider: 0.511
# case: 0.511
# malwar: 0.511
# question: 0.511
# size: 0.511
# penalti: 0.511
# reclaim: 0.511
# aris: 0.511
# vari: 0.511
# impos: 0.511
# septemb: 0.511
# day: 0.511
# inhibit: 0.511
# channel: 0.511
# repurchas: 0.511
# detect: 0.511
# sophist: 0.511
# free: 0.511
# might: 0.511
# statutori: 0.511
# analyst: 0.511
# consid: 0.511
# end: 0.511
# prior: 0.511
# degrad: 0.511
# reform: 0.511
# recent: 0.511
# sector: 0.511
# group: 0.511
# disast: 0.511
# unbundl: 2.303
# entranc: 2.303
# misstat: 2.303
# averag: 2.303
# manageri: 2.303
# uphold: 2.303
# spring: 2.303
# clearanc: 2.303
# opt: 2.303
# portal: 2.303
# involuntari: 2.303
# marketl: 2.303
# rulemak: 2.303
# wider: 2.303
# idea: 2.303
# pin: 2.303
# multichannel: 2.303
# snowfal: 2.303
# hce: 2.303
# nsa: 2.303
# exhibit: 2.303
# aussi: 2.303
# dramat: 2.303
# qiwi: 2.303
# doj: 2.303
# warm: 2.303
# viabil: 2.303
# nonetheless: 2.303
# payfon: 2.303
# timelin: 2.303
# voidabl: 2.303
# weight: 2.303
# pdf: 2.303
# accordion: 2.303
# emul: 2.303
# distract: 2.303
# core: 2.303
# advis: 2.303
# law: 2.303
# attrit: 2.303
# outparcel: 2.303
# hawaii: 2.303
# taiwanes: 2.303
# slowdown: 2.303
# popular: 2.303
# groceri: 2.303
# chariti: 2.303
# overstock: 2.303
# seritag: 2.303
# infect: 2.303
# phase: 2.303
# deni: 2.303
# pretax: 2.303
# unpaid: 2.303
# paylib: 2.303
# proactiv: 2.303
# lawuit: 2.303
# publish: 2.303
# rhode: 2.303
# donat: 2.303
# dual: 2.303
# certiorari: 2.303
# adob: 2.303
# stanley: 2.303
# aliexpress: 2.303
# mif: 2.303
# await: 2.303
# resum: 2.303
# masterpass: 2.303
# formal: 2.303
# radio: 2.303
# seamless: 2.303
# factori: 2.303
# counterparti: 2.303
# izettl: 2.303
# dakota: 2.303
# occasion: 2.303
# pte: 2.303
# multilater: 2.303
# highest: 2.303
# bandwidth: 2.303
# decker: 2.303
# enrol: 2.303
# outlot: 2.303
# icahn: 2.303
# judiciari: 2.303
# port: 2.303
# reject: 2.303
# seq: 2.303
# dedic: 2.303
# unreason: 2.303
# redeem: 2.303
# convey: 2.303
# mall: 2.303
# recruit: 2.303
# collater: 2.303
# disallow: 2.303
# deadlin: 2.303
# finanzmarktaufsicht: 2.303
# divid: 2.303
# grind: 2.303
# cid: 2.303
# signal: 2.303
# complementari: 2.303
# destroy: 2.303
# android: 2.303
# golden: 2.303
# exacerb: 2.303
# outlet: 2.303
# hamburg: 2.303
# unseason: 2.303
# ceo: 2.303
# sumup: 2.303
# dfi: 2.303
# precash: 2.303
# homepag: 2.303
# consecut: 2.303
# payrol: 2.303
# login: 2.303
# dan: 2.303
# alloc: 2.303
# backbon: 2.303
# zong: 2.303
# journey: 2.303
# michael: 2.303
# warrior: 2.303
# winter: 2.303
# infiltr: 2.303
# discus: 2.303
# seoul: 2.303
# occupi: 2.303
# disproportion: 2.303
# dutch: 2.303
# dampen: 2.303
# groupon: 2.303
# travel: 2.303
# leaseback: 2.303
# devin: 2.303
# dominion: 2.303
# craftsman: 2.303
# conting: 2.303
# guaranti: 2.303
# space: 2.303
# storm: 2.303
# token: 2.303
# greec: 2.303
# bargain: 2.303
# wenig: 2.303
# pictur: 2.303
# rainstorm: 2.303
# contraven: 2.303
# simon: 2.303
# deflat: 2.303
# breadth: 2.303
# pco: 2.303
# heavi: 2.303
# exercis: 2.303
# governor: 2.303
# characterist: 2.303
# packag: 2.303
# cashedg: 2.303
# nativ: 2.303
# assessor: 2.303
# forbear: 2.303
# ratio: 2.303
# zashpay: 2.303
# lesser: 2.303
# pad: 2.303
# bafin: 2.303
# assum: 2.303
# macerich: 2.303
# centric: 2.303
# shutdown: 2.303
# half: 2.303
# park: 2.303
# divis: 2.303
# fictiti: 2.303
# dehand: 2.303
# oztion: 2.303
# footprint: 2.303
# beacon: 2.303
# schedul: 2.303
# black: 2.303
# temperatur: 2.303
# herein: 2.303
# finanzdienstleistungsaufsicht: 2.303
# automot: 2.303
# testimoni: 2.303
# synchroni: 2.303
# character: 2.303
# save: 2.303
# premis: 2.303
# capitol: 2.303
# affirm: 2.303
# workforc: 2.303
# thereaft: 2.303
# cloud: 2.303
# chair: 2.303
# austrian: 2.303
# austria: 2.303
# writ: 2.303
# statist: 2.303
# cooper: 2.303
# object: 2.303
# arkansa: 2.303
# bundl: 2.303
# copi: 2.303
# merg: 2.303
# wangfuyi: 2.303
# legaci: 2.303
# oppos: 2.303
# healthcar: 2.303
# ration: 2.303
# master: 2.303
# fma: 2.303
# sdks: 2.303
# bind: 2.303
# ring: 2.303
# hand: 2.303
# belgium: 2.303
# kmart: 2.303
# bipartisan: 2.303
# wherebi: 2.303
# paym: 2.303
# pool: 2.303
# modular: 2.303
# hacker: 2.303
# recaptur: 2.303
# reward: 2.303
# pci: 2.303
# landscap: 2.303
# quicksal: 2.303
# proxim: 2.303
# ice: 2.303
# smartphon: 2.303
# scotland: 2.303
# shopifi: 2.303
# royal: 2.303
# repair: 2.303
# stay: 2.303
# navig: 2.303
# rubin: 2.303
# hometown: 2.303
# submiss: 2.303
# next: 2.303
# hill: 2.303
# partial: 2.303
# payleven: 2.303
# modif: 2.303
# bundesanstalt: 2.303
# awar: 2.303
# committe: 2.303
# counteract: 2.303
# turnov: 2.303
# leas: 2.303
# peer: 2.303
# late: 2.303
# proxi: 2.303
# shanghai: 2.303
# pboc: 2.303
# discern: 2.303
# schulman: 2.303
# bolster: 2.303
# prepar: 2.303
# pbgc: 2.303
# contactless: 2.303

# %% [markdown]
# <a id="compute_tf"></a>

# %% [markdown]
# ## 4. Compute tf
#
# Below we will compute ${\rm tf}(w,d)$, or the term frequency for a given word $w$, in a given document $d$. Since our ultimate goal is to compute a document vector, we'd like to keep a few things in mind
#
# 1. Store the ${\rm tf}(w, d)$ for each word in a document as a dictionary
# 2. Even when a word doesn't appear in the document $d$, we still want to keep a $0$ entry in the dictionary. This is important when we convert the dictionary to a vector, where zero entries are important
#
#
# There are multiple definitions for ${\rm tf}(w,d)$, the simplest one is
#
# $$
# {\rm tf}(w,d)=\frac{f_{w,d}}{a_d}
# $$
#
# where $f_{w,d}$ is the number of occurence of the word $w$ in the document $d$, and $a$ the average occurence of all the words in that document for normalization. Just like ${\rm idf}(w)$, a logarithm can be added
#
# $$
# {\rm tf}(w,d)=\begin{cases}
# \frac{1+\log f_{w,d}}{1+\log a_d} & f_{w,d} > 0 \\
# 0 & f_{w,d} = 0 \\
# \end{cases}
# $$
#
# Implement the function `get_df(txt, include_log=True)` that computes ${\rm tf}(w,d)$ for each word in the document (returns a defaultdict(int), so that when supplying words not in the document the dictionary will yield zero instead of an error). Also include the optional parameter `include_log` that enables the additional logarithm term in the computation. I suggest also adding a function called `_tf` that computes the function above.
#
# <a href="#table_of_content">back to top</a>

# %%
import numpy as np
from math import *

def _tf(freq, avg, include_log=True):
    # TO DO
    if include_log:
        return 0 if freq == 0 else (1+ np.log(freq)) / (1 + np.log(avg))
    else:
        return freq/avg

def get_tf(txt, include_log=True):
    # TO DO
    freq = bag_of_words(txt)
    avg = np.mean(list(freq.values()))
    tf = {w:_tf(f,avg, include_log) for w,f in freq.items()}
    return defaultdict(int, tf)

# %%
tfs = [ get_tf(c) for c in corpus ]
print_sorted(tfs[0])
# Out:
# paypal: 2.090
# payment: 1.989
# increas: 1.902
# custom: 1.900
# regul: 1.837
# provid: 1.824
# addit: 1.815
# transact: 1.803
# new: 1.796
# use: 1.791
# seller: 1.778
# websit: 1.770
# gsi: 1.764
# abil: 1.747
# consum: 1.744
# oper: 1.735
# harm: 1.729
# certain: 1.723
# subject: 1.717
# mobil: 1.707
# internet: 1.704
# time: 1.693
# onlin: 1.690
# ebay: 1.686
# advers: 1.679
# relat: 1.672
# offer: 1.660
# card: 1.660
# sale: 1.657
# site: 1.657
# would: 1.653
# risk: 1.649
# bank: 1.649
# affect: 1.645
# client: 1.645
# signific: 1.628
# action: 1.628
# buyer: 1.628
# platform: 1.619
# fund: 1.619
# bill: 1.619
# continu: 1.615
# revenu: 1.615
# reassess: 0.647
# gst: 0.647
# hst: 0.647
# incent: 0.647
# certif: 0.647
# ensur: 0.647
# sometim: 0.647
# vendor: 0.647
# environ: 0.647
# minimum: 0.647
# downtim: 0.647
# hardwar: 0.647
# necessari: 0.647
# hour: 0.647
# gain: 0.647
# earthquak: 0.647
# hurrican: 0.647
# human: 0.647
# geographi: 0.647
# scale: 0.647
# incid: 0.647
# council: 0.647
# cycl: 0.647
# abroad: 0.647
# neighbor: 0.647
# serv: 0.647
# strategi: 0.647
# ineffici: 0.647
# incorpor: 0.647
# realiz: 0.647
# vote: 0.647
# intershop: 0.647
# craigslist: 0.647
# optim: 0.647
# team: 0.647
# lockout: 0.647
# game: 0.647
# senior: 0.647
# motiv: 0.647
# carrier: 0.647
# bing: 0.647
# horizont: 0.647
# instead: 0.647
# american: 0.647
# mcx: 0.647
# netherland: 0.647
# skrill: 0.647
# paymat: 0.647
# kit: 0.647
# enterpris: 0.647
# react: 0.647
# holiday: 0.647
# hire: 0.647
# revolv: 0.647
# capac: 0.647
# assign: 0.647
# refin: 0.647
# domain: 0.647
# prolong: 0.522
# spillov: 0.522
# rest: 0.522
# contagion: 0.522
# spread: 0.522
# dissolut: 0.522
# replatform: 0.522
# cart: 0.522
# basket: 0.522
# navig: 0.522
# redesign: 0.522
# imag: 0.522
# weak: 0.522
# administ: 0.522
# stem: 0.522
# tran: 0.522
# cosmet: 0.522
# perfum: 0.522
# wall: 0.522
# monet: 0.522
# healthi: 0.522
# supplier: 0.522
# spywar: 0.522
# danger: 0.522
# investor: 0.522
# heavili: 0.522
# unexpect: 0.522
# shortfal: 0.522
# reflect: 0.522
# controversi: 0.522
# elect: 0.522
# mix: 0.522
# elig: 0.522
# economi: 0.522
# movement: 0.522
# day: 0.522
# worsen: 0.522
# hedg: 0.522
# korean: 0.522
# imposs: 0.522
# reach: 0.522
# true: 0.522
# version: 0.522
# sca: 0.522
# passport: 0.522
# notif: 0.522
# newli: 0.522
# bafin: 0.522
# fma: 0.522
# depositori: 0.522
# wangfuyi: 0.522
# pboc: 0.522
# pco: 0.522
# license: 0.522
# payabl: 0.522
# deposit: 0.522
# guidelin: 0.522
# permit: 0.522
# alon: 0.522
# allianc: 0.522
# registr: 0.522
# hong: 0.522
# kong: 0.522
# suspici: 0.522
# prepay: 0.522
# monitor: 0.522
# austrac: 0.522
# second: 0.522
# devinda: 0.522
# fernando: 0.522
# vadim: 0.522
# tsigel: 0.522
# mois: 0.522
# zepeda: 0.522
# mandat: 0.522
# status: 0.522
# cap: 0.522
# deploy: 0.522
# typic: 0.522
# threaten: 0.522
# christian: 0.522
# dior: 0.522
# coutur: 0.522
# doctrin: 0.522
# ninth: 0.522
# narrow: 0.522
# abet: 0.522
# earlier: 0.522
# particip: 0.522
# except: 0.522
# percept: 0.522
# goal: 0.522
# mitig: 0.522
# piraci: 0.522
# judici: 0.522
# indemnifi: 0.522
# sole: 0.522
# meritori: 0.522
# prosecutor: 0.522
# alreadi: 0.522
# august: 0.522
# visibl: 0.522
# scalp: 0.522
# discontinu: 0.522
# reluct: 0.522
# child: 0.522
# play: 0.522
# unbundl: 0.522
# analyt: 0.522
# prepared: 0.522
# roll: 0.522
# libel: 0.522
# forum: 0.522
# bid: 0.522
# broad: 0.522
# question: 0.522
# educ: 0.522
# preclud: 0.522
# surcharg: 0.522
# recoup: 0.522
# concert: 0.522
# deal: 0.522
# knowledg: 0.522
# circumv: 0.522
# sophist: 0.522
# fraudster: 0.522
# discov: 0.522
# match: 0.522
# recov: 0.522
# sort: 0.522
# clarifi: 0.522
# mechan: 0.522
# combat: 0.522
# impract: 0.522
# disclos: 0.522
# sabotag: 0.522
# routin: 0.522
# server: 0.522
# break: 0.522
# seri: 0.522
# releas: 0.522
# senat: 0.522
# decre: 0.522
# facebook: 0.522
# settl: 0.522
# undergo: 0.522
# recommend: 0.522
# pursu: 0.522
# conform: 0.522
# via: 0.522
# text: 0.522
# monetari: 0.522
# sensit: 0.522
# placement: 0.522
# den: 0.522
# bla: 0.522
# avi: 0.522
# bilbasen: 0.522
# anuncio: 0.522
# kleinanzeigen: 0.522
# annunci: 0.522
# gumtre: 0.522
# kijiji: 0.522
# loquo: 0.522
# marktplaat: 0.522
# alamaula: 0.522
# milo: 0.522
# alway: 0.522
# threat: 0.522
# ban: 0.522
# health: 0.522
# passag: 0.522
# headquart: 0.522
# constitut: 0.522
# cannot: 0.522
# oversight: 0.522
# threshold: 0.522
# sign: 0.522
# nexus: 0.522
# judg: 0.522
# unconstitut: 0.522
# exclud: 0.522
# calendar: 0.522
# remot: 0.522
# owe: 0.522
# certifi: 0.522
# discriminatori: 0.522
# april: 0.522
# cra: 0.522
# calcul: 0.522
# withhold: 0.522
# input: 0.522
# reclaim: 0.522
# score: 0.522
# willing: 0.522
# uncollect: 0.522
# nonpay: 0.522
# reader: 0.522
# unless: 0.522
# nomin: 0.522
# defer: 0.522
# short: 0.522
# intermitt: 0.522
# three: 0.522
# unschedul: 0.522
# persist: 0.522
# occurr: 0.522
# flood: 0.522
# fire: 0.522
# defect: 0.522
# malfunct: 0.522
# redund: 0.522
# unanticip: 0.522
# updat: 0.522
# transport: 0.522
# month: 0.522
# strong: 0.522
# transmit: 0.522
# preced: 0.522
# ambival: 0.522
# worker: 0.522
# stringent: 0.522
# adapt: 0.522
# filter: 0.522
# contractor: 0.522
# isra: 0.522
# hostil: 0.522
# dilut: 0.522
# riski: 0.522
# unforeseen: 0.522
# moral: 0.522
# onto: 0.522
# unknown: 0.522
# write: 0.522
# theft: 0.522
# inabl: 0.522
# unwant: 0.522
# mail: 0.522
# worm: 0.522
# divestitur: 0.522
# resel: 0.522
# superior: 0.522
# stoppag: 0.522
# dynam: 0.522
# much: 0.522
# renew: 0.522
# vast: 0.522
# postal: 0.522
# therebi: 0.522
# outsourc: 0.522
# poor: 0.522
# barrier: 0.522
# home: 0.522
# naver: 0.522
# destin: 0.522
# communiti: 0.522
# innov: 0.522
# adida: 0.522
# walmart: 0.522
# squar: 0.522
# paymentech: 0.522
# worldpay: 0.522
# stripe: 0.522
